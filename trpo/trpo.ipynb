# %%
### Resources:

# Conjugate Gradient: https://en.wikipedia.org/wiki/Conjugate_gradient_method

# TRPO: https://spinningup.openai.com/en/latest/algorithms/trpo.html#id9

# TRPO Paper: https://arxiv.org/abs/1502.05477

# %%
import os
import gym
import torch
from torch import nn
import numpy as np
from spinup import trpo_tf1 as trpo
from spinup.utils.run_utils import setup_logger_kwargs

from models import MLPActorCritic, MLPActorDiscrete
from train import TRPOTrainer

# %%
### Test policy copying

obs_dim, act_dim = 3, 2
hidden_sizes, hidden_acts = [64, 64], nn.Tanh

actor_1 = MLPActorDiscrete(obs_dim, act_dim, hidden_sizes, hidden_acts)
actor_2 = MLPActorDiscrete(obs_dim, act_dim, hidden_sizes, hidden_acts)

# Test that they're different initially
input = torch.randn(obs_dim)
print('Before copying:\n')
print(f'Output 1 = {actor_1.net(input)}\t', f'Output 2 = {actor_2.net(input)}\n\n')

# Copy the new policy into the prev one
params_flat = nn.utils.parameters_to_vector(actor_1.net.parameters())
nn.utils.vector_to_parameters(params_flat, actor_2.net.parameters())
print(f'After policy copy:\n')
print(f'Output 1 = {actor_1.net(input)}\t', f'Output 2 = {actor_2.net(input)}\n\n')

# Update weights of new policy after deep copy
params_new = torch.randn_like(params_flat)
nn.utils.vector_to_parameters(params_new, actor_1.net.parameters())
print(f'After weight update for new policy:\n')
print(f'Output 1 = {actor_1.net(input)}\t', f'Output 2 = {actor_2.net(input)}\n\n')
# Out:
# Before copying:
#
# Output 1 = tensor([-0.0695,  0.3696], grad_fn=<AddBackward0>)	 Output 2 = tensor([ 0.0169, -0.1111], grad_fn=<AddBackward0>)
#
#
# After policy copy:
#
# Output 1 = tensor([-0.0695,  0.3696], grad_fn=<AddBackward0>)	 Output 2 = tensor([-0.0695,  0.3696], grad_fn=<AddBackward0>)
#
#
# After weight update for new policy:
#
# Output 1 = tensor([-0.9688, -4.7047], grad_fn=<AddBackward0>)	 Output 2 = tensor([-0.0695,  0.3696], grad_fn=<AddBackward0>)

# %%
### Test automatic gradient calculation using autograd

# Initialize actor
obs_dim, act_dim = 3, 2
hidden_sizes, hidden_acts = [64, 64], nn.Tanh
actor = MLPActorDiscrete(obs_dim, act_dim, hidden_sizes, hidden_acts)

# Calculate the KL-Divergence
obs = np.random.randn(400, 3)
act = actor.forward(torch.as_tensor(obs, dtype=torch.float32))
logp = actor.log_prob_grad(torch.as_tensor(obs, dtype=torch.float32), 
                           torch.as_tensor(act, dtype=torch.float32))
kl = actor.kl_divergence_grad(torch.as_tensor(obs, dtype=torch.float32))
print(kl, kl.requires_grad, '\n\n')

# Calculate the gradient of KL w.r.t. model parameters
print('\nFlattening gradients:\n')
grad = torch.autograd.grad(kl, actor.net.parameters(), create_graph=True)
grad = torch.cat([g.flatten() for g in grad])
x_vec = torch.ones_like(grad)

def get_grad_2(grad_flat: torch.Tensor, x: torch.Tensor, actor: MLPActorDiscrete, retain=False):
    output_2 = torch.dot(grad_flat, x)
    grad_2 = torch.autograd.grad(output_2, actor.net.parameters(), retain_graph=retain)
    
    return grad_2

for i in range(3):
    grad_2 = get_grad_2(grad, x_vec, actor, retain=(i!=2))
    print(len(grad_2), grad_2[0][:6], '\n\n')
# Out:
# tensor(0., grad_fn=<MeanBackward0>) True
#
#
#
# Flattening gradients:
#
# 6 tensor([[-2.3952e-04,  7.7479e-03,  6.5625e-03],
#         [ 3.2518e-05, -1.0357e-03, -6.2778e-04],
#         [-1.6083e-04, -9.1544e-04, -4.8676e-04],
#         [ 1.0323e-03,  6.2841e-03,  5.8161e-03],
#         [ 3.0933e-05,  5.0234e-03,  3.2694e-03],
#         [ 2.2753e-04, -4.3374e-03, -3.6200e-03]])
#
#
# 6 tensor([[-2.3952e-04,  7.7479e-03,  6.5625e-03],
#         [ 3.2518e-05, -1.0357e-03, -6.2778e-04],
#         [-1.6083e-04, -9.1544e-04, -4.8676e-04],
#         [ 1.0323e-03,  6.2841e-03,  5.8161e-03],
#         [ 3.0933e-05,  5.0234e-03,  3.2694e-03],
#         [ 2.2753e-04, -4.3374e-03, -3.6200e-03]])
#
#
# 6 tensor([[-2.3952e-04,  7.7479e-03,  6.5625e-03],
#         [ 3.2518e-05, -1.0357e-03, -6.2778e-04],
#         [-1.6083e-04, -9.1544e-04, -4.8676e-04],
#         [ 1.0323e-03,  6.2841e-03,  5.8161e-03],
#         [ 3.0933e-05,  5.0234e-03,  3.2694e-03],
#         [ 2.2753e-04, -4.3374e-03, -3.6200e-03]])

# %%
### Test entropy calculation for Categorical distribution

# Initialize actor
obs_dim, act_dim = 3, 2
hidden_sizes, hidden_acts = [64, 64], nn.Tanh
actor = MLPActorDiscrete(obs_dim, act_dim, hidden_sizes, hidden_acts)

# Calculate the Entropy of the policy
obs = np.random.randn(40, 3)
act = actor.forward(torch.as_tensor(obs, dtype=torch.float32))
logp = actor.log_prob_grad(torch.as_tensor(obs, dtype=torch.float32), 
                           torch.as_tensor(act, dtype=torch.float32))
entropy = actor.pi.entropy()

print(f'First 5 elements of entropy {entropy[:5]}\n', f'Entropy shape {entropy.shape}\n', f'Entropy mean {entropy.mean()}')
# Out:
# First 5 elements of entropy tensor([0.6818, 0.6860, 0.6663, 0.6868, 0.6928], grad_fn=<SliceBackward>)
#  Entropy shape torch.Size([40])
#  Entropy mean 0.6889864206314087

# %%
### Test manual parameter updates for NNs

mlp_net = nn.Sequential(nn.Linear(2, 6), nn.ReLU(), nn.Linear(6, 1))
params_flat = nn.utils.parameters_to_vector(mlp_net.parameters())
print(f'Initial parameters:\n{params_flat.detach()}\n\n')

# Add offset to parameters and update them
offset_flat = torch.ones_like(params_flat)
nn.utils.vector_to_parameters(params_flat + offset_flat, mlp_net.parameters())
params_flat = nn.utils.parameters_to_vector(mlp_net.parameters())
print(f'Parameters after update:\n{params_flat.detach()}\n\n')
# Out:
# Initial parameters:
# tensor([-0.2241, -0.4701, -0.0195,  0.2474,  0.2873, -0.3175,  0.4951,  0.1695,
#         -0.0775,  0.5563, -0.3664,  0.1876,  0.5165, -0.0506, -0.1947,  0.0188,
#         -0.2806, -0.5027, -0.1864, -0.2142, -0.3837,  0.2707,  0.3780, -0.3621,
#         -0.1718])
#
#
# Parameters after update:
# tensor([0.7759, 0.5299, 0.9805, 1.2474, 1.2873, 0.6825, 1.4951, 1.1695, 0.9225,
#         1.5563, 0.6336, 1.1876, 1.5165, 0.9494, 0.8053, 1.0188, 0.7194, 0.4973,
#         0.8136, 0.7858, 0.6163, 1.2707, 1.3780, 0.6379, 0.8282])

# %%
### Define parameters needed for training

env_fn = lambda : gym.make('CartPole-v1')

# AC module parameters
hidden_sizes_actor, hidden_sizes_critic = [64, 64], [64, 64]
hidden_acts_actor, hidden_acts_critic = nn.Tanh, nn.Tanh
ac_kwargs = dict(hidden_sizes_actor=hidden_sizes_actor, 
                 hidden_sizes_critic=hidden_sizes_critic,
                 hidden_acts_actor=hidden_acts_actor, 
                 hidden_acts_critic=hidden_acts_critic)

# Training parameters
seed = 0
steps_per_epoch, max_ep_len, epochs = 4000, 1000, 50 
gamma, lam = 0.99, 0.97 
delta, surr_obj_min = 0.01, 0.003
vf_lr, train_v_iters = 1e-3, 80
damping_coeff, cg_iters = 0.1, 10
backtrack_iters, backtrack_coeff = 10, 0.8 
save_freq = 10

# Experiment parameters
data_dir = '/home/sherif/user/python/DRL/data/trpo'
exp_name_spinup = 'trpo_spinup_discrete'
exp_name_custom = 'trpo_custom_discrete'

# %%
### Perform training experiment with the Spinup TRPO implementation

logger_kwargs = setup_logger_kwargs(exp_name=exp_name_spinup, data_dir=data_dir)

trpo(env_fn, ac_kwargs=dict(hidden_sizes=hidden_sizes_actor), seed=seed,
     steps_per_epoch=steps_per_epoch, epochs=epochs, gamma=gamma, delta=delta,
     vf_lr=vf_lr, train_v_iters=train_v_iters, damping_coeff=damping_coeff,
     cg_iters=cg_iters, backtrack_iters=backtrack_iters, 
     backtrack_coeff=backtrack_coeff, lam=lam, max_ep_len=max_ep_len,
     logger_kwargs=logger_kwargs, save_freq=save_freq)
# Out:
# Warning: Log dir /home/sherif/user/python/DRL/data/trpo/trpo_spinup_discrete already exists! Storing info there anyway.
# Logging data to /home/sherif/user/python/DRL/data/trpo/trpo_spinup_discrete/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "actor_critic":	"mlp_actor_critic",
#     "algo":	"trpo",
#     "backtrack_coeff":	0.8,
#     "backtrack_iters":	10,
#     "cg_iters":	10,
#     "damping_coeff":	0.1,
#     "delta":	0.01,
#     "env_fn":	"<function <lambda> at 0x748f1a9ae730>",
#     "epochs":	50,
#     "exp_name":	"trpo_spinup_discrete",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x748f1a99e198>":	{
#             "epoch_dict":	{},
#             "exp_name":	"trpo_spinup_discrete",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/home/sherif/user/python/DRL/data/trpo/trpo_spinup_discrete",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/home/sherif/user/python/DRL/data/trpo/trpo_spinup_discrete/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"trpo_spinup_discrete",
#         "output_dir":	"/home/sherif/user/python/DRL/data/trpo/trpo_spinup_discrete"
#     },
#     "max_ep_len":	1000,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000,
#     "train_v_iters":	80,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 4610, 	 v: 4545
# /home/sherif/miniconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Warning: trajectory cut off by epoch at 4 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            26.1 |
# |          StdEpRet |            15.1 |
# |          MaxEpRet |              91 |
# |          MinEpRet |              10 |
# |             EpLen |            26.1 |
# |      AverageVVals |         -0.0227 |
# |          StdVVals |           0.446 |
# |          MaxVVals |            1.51 |
# |          MinVVals |            -1.4 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |        9.78e-09 |
# |             LossV |             375 |
# |       DeltaLossPi |         -0.0223 |
# |        DeltaLossV |            -214 |
# |                KL |         0.00906 |
# |    BacktrackIters |               0 |
# |              Time |            1.23 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 20 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            37.9 |
# |          StdEpRet |            18.4 |
# |          MaxEpRet |              87 |
# |          MinEpRet |              11 |
# |             EpLen |            37.9 |
# |      AverageVVals |            9.99 |
# |          StdVVals |           0.453 |
# |          MaxVVals |            10.9 |
# |          MinVVals |            6.32 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |       -4.22e-08 |
# |             LossV |             270 |
# |       DeltaLossPi |          -0.019 |
# |        DeltaLossV |            -110 |
# |                KL |         0.00805 |
# |    BacktrackIters |               0 |
# |              Time |            2.15 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 48 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            47.6 |
# |          StdEpRet |            28.8 |
# |          MaxEpRet |             142 |
# |          MinEpRet |              13 |
# |             EpLen |            47.6 |
# |      AverageVVals |            19.2 |
# |          StdVVals |            1.95 |
# |          MaxVVals |            21.3 |
# |          MinVVals |            5.63 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |        4.15e-08 |
# |             LossV |             343 |
# |       DeltaLossPi |         -0.0218 |
# |        DeltaLossV |           -66.5 |
# |                KL |         0.00836 |
# |    BacktrackIters |               0 |
# |              Time |            3.07 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 5 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            81.5 |
# |          StdEpRet |            52.1 |
# |          MaxEpRet |             322 |
# |          MinEpRet |              17 |
# |             EpLen |            81.5 |
# |      AverageVVals |            24.2 |
# |          StdVVals |            4.12 |
# |          MaxVVals |            26.6 |
# |          MinVVals |           -2.82 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |       -1.08e-08 |
# |             LossV |             682 |
# |       DeltaLossPi |         -0.0189 |
# |        DeltaLossV |            -195 |
# |                KL |         0.00887 |
# |    BacktrackIters |               0 |
# |              Time |            3.98 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 12 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |             133 |
# |          StdEpRet |            57.9 |
# |          MaxEpRet |             251 |
# |          MinEpRet |              20 |
# |             EpLen |             133 |
# |      AverageVVals |              32 |
# |          StdVVals |            5.12 |
# |          MaxVVals |            35.2 |
# |          MinVVals |            2.76 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |       -3.58e-09 |
# |             LossV |             797 |
# |       DeltaLossPi |          -0.016 |
# |        DeltaLossV |            -224 |
# |                KL |          0.0079 |
# |    BacktrackIters |               0 |
# |              Time |            4.91 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 263 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             220 |
# |          StdEpRet |            80.1 |
# |          MaxEpRet |             384 |
# |          MinEpRet |             104 |
# |             EpLen |             220 |
# |      AverageVVals |            39.7 |
# |          StdVVals |            6.15 |
# |          MaxVVals |            43.5 |
# |          MinVVals |            12.5 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |        9.13e-08 |
# |             LossV |        1.07e+03 |
# |       DeltaLossPi |         -0.0117 |
# |        DeltaLossV |            -402 |
# |                KL |          0.0069 |
# |    BacktrackIters |               0 |
# |              Time |            5.84 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 171 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             295 |
# |          StdEpRet |             127 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             106 |
# |             EpLen |             295 |
# |      AverageVVals |            47.6 |
# |          StdVVals |            9.97 |
# |          MaxVVals |            53.2 |
# |          MinVVals |            1.66 |
# | TotalEnvInteracts |         2.8e+04 |
# |            LossPi |        5.84e-08 |
# |             LossV |             932 |
# |       DeltaLossPi |         -0.0109 |
# |        DeltaLossV |            -353 |
# |                KL |         0.00778 |
# |    BacktrackIters |               0 |
# |              Time |            6.75 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 151 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             321 |
# |          StdEpRet |             119 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             139 |
# |             EpLen |             321 |
# |      AverageVVals |            54.5 |
# |          StdVVals |            13.3 |
# |          MaxVVals |            61.3 |
# |          MinVVals |            12.9 |
# | TotalEnvInteracts |         3.2e+04 |
# |            LossPi |       -1.96e-08 |
# |             LossV |             731 |
# |       DeltaLossPi |        -0.00355 |
# |        DeltaLossV |            -296 |
# |                KL |         0.00716 |
# |    BacktrackIters |               0 |
# |              Time |            7.68 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 406 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             399 |
# |          StdEpRet |             113 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             150 |
# |             EpLen |             399 |
# |      AverageVVals |            64.3 |
# |          StdVVals |            8.62 |
# |          MaxVVals |            67.1 |
# |          MinVVals |            14.7 |
# | TotalEnvInteracts |         3.6e+04 |
# |            LossPi |       -2.36e-08 |
# |             LossV |             647 |
# |       DeltaLossPi |        -0.00455 |
# |        DeltaLossV |            -110 |
# |                KL |         0.00648 |
# |    BacktrackIters |               0 |
# |              Time |            8.59 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 223 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             472 |
# |          StdEpRet |            73.8 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             277 |
# |             EpLen |             472 |
# |      AverageVVals |            70.8 |
# |          StdVVals |             2.6 |
# |          MaxVVals |            71.8 |
# |          MinVVals |            53.1 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |        -1.4e-08 |
# |             LossV |             666 |
# |       DeltaLossPi |         -0.0044 |
# |        DeltaLossV |           -54.4 |
# |                KL |         0.00764 |
# |    BacktrackIters |               0 |
# |              Time |            9.52 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            74.7 |
# |          StdVVals |            1.53 |
# |          MaxVVals |              75 |
# |          MinVVals |              52 |
# | TotalEnvInteracts |         4.4e+04 |
# |            LossPi |         1.1e-08 |
# |             LossV |             630 |
# |       DeltaLossPi |        -0.00517 |
# |        DeltaLossV |           -22.8 |
# |                KL |         0.00924 |
# |    BacktrackIters |               0 |
# |              Time |            10.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 65 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             358 |
# |          StdEpRet |             124 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             175 |
# |             EpLen |             358 |
# |      AverageVVals |            76.5 |
# |          StdVVals |            2.85 |
# |          MaxVVals |            77.2 |
# |          MinVVals |            48.5 |
# | TotalEnvInteracts |         4.8e+04 |
# |            LossPi |         3.1e-09 |
# |             LossV |             611 |
# |       DeltaLossPi |        -0.00547 |
# |        DeltaLossV |            -288 |
# |                KL |          0.0088 |
# |    BacktrackIters |               0 |
# |              Time |            11.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 203 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             271 |
# |          StdEpRet |              89 |
# |          MaxEpRet |             464 |
# |          MinEpRet |             164 |
# |             EpLen |             271 |
# |      AverageVVals |            66.4 |
# |          StdVVals |            20.4 |
# |          MaxVVals |            78.8 |
# |          MinVVals |            15.9 |
# | TotalEnvInteracts |         5.2e+04 |
# |            LossPi |       -2.35e-08 |
# |             LossV |             128 |
# |       DeltaLossPi |        -0.00885 |
# |        DeltaLossV |           -38.4 |
# |                KL |         0.00958 |
# |    BacktrackIters |               0 |
# |              Time |            12.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 114 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             389 |
# |          StdEpRet |            95.9 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             229 |
# |             EpLen |             389 |
# |      AverageVVals |            68.7 |
# |          StdVVals |            18.3 |
# |          MaxVVals |            80.3 |
# |          MinVVals |            12.5 |
# | TotalEnvInteracts |         5.6e+04 |
# |            LossPi |        2.13e-08 |
# |             LossV |             318 |
# |       DeltaLossPi |        -0.00473 |
# |        DeltaLossV |           -69.2 |
# |                KL |         0.00592 |
# |    BacktrackIters |               0 |
# |              Time |            13.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 121 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             485 |
# |          StdEpRet |              40 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             379 |
# |             EpLen |             485 |
# |      AverageVVals |            77.9 |
# |          StdVVals |            12.3 |
# |          MaxVVals |            82.6 |
# |          MinVVals |            15.9 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |        2.13e-08 |
# |             LossV |             410 |
# |       DeltaLossPi |        -0.00398 |
# |        DeltaLossV |             -48 |
# |                KL |          0.0076 |
# |    BacktrackIters |               0 |
# |              Time |            14.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 159 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             480 |
# |          StdEpRet |            52.6 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             341 |
# |             EpLen |             480 |
# |      AverageVVals |            77.4 |
# |          StdVVals |            7.97 |
# |          MaxVVals |            84.7 |
# |          MinVVals |            53.1 |
# | TotalEnvInteracts |         6.4e+04 |
# |            LossPi |       -8.34e-09 |
# |             LossV |             532 |
# |       DeltaLossPi |        -0.00734 |
# |        DeltaLossV |           -44.9 |
# |                KL |         0.00887 |
# |    BacktrackIters |               0 |
# |              Time |              15 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.2 |
# |          StdVVals |            8.16 |
# |          MaxVVals |            85.6 |
# |          MinVVals |            7.02 |
# | TotalEnvInteracts |         6.8e+04 |
# |            LossPi |       -1.19e-09 |
# |             LossV |             539 |
# |       DeltaLossPi |        -0.00453 |
# |        DeltaLossV |           -90.5 |
# |                KL |         0.00832 |
# |    BacktrackIters |               0 |
# |              Time |            15.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 339 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             407 |
# |          StdEpRet |            90.8 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             276 |
# |             EpLen |             407 |
# |      AverageVVals |              78 |
# |          StdVVals |            16.5 |
# |          MaxVVals |            84.9 |
# |          MinVVals |             2.5 |
# | TotalEnvInteracts |         7.2e+04 |
# |            LossPi |       -6.26e-09 |
# |             LossV |             495 |
# |       DeltaLossPi |        -0.00649 |
# |        DeltaLossV |           -98.2 |
# |                KL |         0.00877 |
# |    BacktrackIters |               0 |
# |              Time |            16.8 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            79.3 |
# |          StdVVals |            9.35 |
# |          MaxVVals |            85.1 |
# |          MinVVals |            37.9 |
# | TotalEnvInteracts |         7.6e+04 |
# |            LossPi |        7.15e-09 |
# |             LossV |             596 |
# |       DeltaLossPi |        -0.00781 |
# |        DeltaLossV |           -67.9 |
# |                KL |         0.00967 |
# |    BacktrackIters |               0 |
# |              Time |            17.7 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            80.5 |
# |          StdVVals |            5.33 |
# |          MaxVVals |            85.1 |
# |          MinVVals |            65.4 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |       -9.54e-10 |
# |             LossV |             533 |
# |       DeltaLossPi |         -0.0053 |
# |        DeltaLossV |           -19.3 |
# |                KL |         0.00873 |
# |    BacktrackIters |               0 |
# |              Time |            18.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             500 |
# |          StdEpRet |           0.331 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             499 |
# |             EpLen |             500 |
# |      AverageVVals |            78.7 |
# |          StdVVals |            7.87 |
# |          MaxVVals |            85.9 |
# |          MinVVals |            57.4 |
# | TotalEnvInteracts |         8.4e+04 |
# |            LossPi |       -4.65e-09 |
# |             LossV |             666 |
# |       DeltaLossPi |        -0.00273 |
# |        DeltaLossV |           -67.2 |
# |                KL |         0.00589 |
# |    BacktrackIters |               0 |
# |              Time |            19.5 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            80.3 |
# |          StdVVals |           0.915 |
# |          MaxVVals |            84.9 |
# |          MinVVals |            75.9 |
# | TotalEnvInteracts |         8.8e+04 |
# |            LossPi |        -1.6e-08 |
# |             LossV |             589 |
# |       DeltaLossPi |        -0.00522 |
# |        DeltaLossV |           -25.5 |
# |                KL |         0.00871 |
# |    BacktrackIters |               0 |
# |              Time |            20.4 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            78.6 |
# |          StdVVals |            2.97 |
# |          MaxVVals |            85.2 |
# |          MinVVals |              70 |
# | TotalEnvInteracts |         9.2e+04 |
# |            LossPi |       -2.62e-09 |
# |             LossV |             568 |
# |       DeltaLossPi |        -0.00296 |
# |        DeltaLossV |           -15.7 |
# |                KL |         0.00738 |
# |    BacktrackIters |               0 |
# |              Time |            21.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 295 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             265 |
# |          StdEpRet |             143 |
# |          MaxEpRet |             500 |
# |          MinEpRet |              87 |
# |             EpLen |             265 |
# |      AverageVVals |            79.2 |
# |          StdVVals |            6.91 |
# |          MaxVVals |            86.2 |
# |          MinVVals |              58 |
# | TotalEnvInteracts |         9.6e+04 |
# |            LossPi |        1.19e-09 |
# |             LossV |             830 |
# |       DeltaLossPi |         -0.0118 |
# |        DeltaLossV |            -263 |
# |                KL |         0.00909 |
# |    BacktrackIters |               0 |
# |              Time |            22.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 81 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             435 |
# |          StdEpRet |             115 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             211 |
# |             EpLen |             435 |
# |      AverageVVals |            71.3 |
# |          StdVVals |            9.47 |
# |          MaxVVals |            78.8 |
# |          MinVVals |            15.2 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |       -1.84e-08 |
# |             LossV |             624 |
# |       DeltaLossPi |        -0.00551 |
# |        DeltaLossV |            -142 |
# |                KL |         0.00961 |
# |    BacktrackIters |               0 |
# |              Time |            23.1 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            80.2 |
# |          StdVVals |            2.79 |
# |          MaxVVals |            86.7 |
# |          MinVVals |            48.3 |
# | TotalEnvInteracts |        1.04e+05 |
# |            LossPi |       -6.68e-09 |
# |             LossV |             583 |
# |       DeltaLossPi |        -0.00219 |
# |        DeltaLossV |             -18 |
# |                KL |         0.00822 |
# |    BacktrackIters |               0 |
# |              Time |              24 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            81.7 |
# |          StdVVals |            3.45 |
# |          MaxVVals |              87 |
# |          MinVVals |            55.4 |
# | TotalEnvInteracts |        1.08e+05 |
# |            LossPi |        -3.1e-09 |
# |             LossV |             575 |
# |       DeltaLossPi |        -0.00215 |
# |        DeltaLossV |           -50.4 |
# |                KL |         0.00655 |
# |    BacktrackIters |               0 |
# |              Time |            24.8 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            81.6 |
# |          StdVVals |            4.62 |
# |          MaxVVals |            87.8 |
# |          MinVVals |            51.1 |
# | TotalEnvInteracts |        1.12e+05 |
# |            LossPi |        1.31e-08 |
# |             LossV |             551 |
# |       DeltaLossPi |        -0.00419 |
# |        DeltaLossV |           -47.5 |
# |                KL |         0.00883 |
# |    BacktrackIters |               0 |
# |              Time |            25.7 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.7 |
# |          StdVVals |            4.89 |
# |          MaxVVals |            87.2 |
# |          MinVVals |            62.4 |
# | TotalEnvInteracts |        1.16e+05 |
# |            LossPi |       -1.43e-09 |
# |             LossV |             590 |
# |       DeltaLossPi |        -0.00186 |
# |        DeltaLossV |           -14.6 |
# |                KL |         0.00804 |
# |    BacktrackIters |               0 |
# |              Time |            26.5 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.1 |
# |          StdVVals |            4.91 |
# |          MaxVVals |            87.1 |
# |          MinVVals |            68.5 |
# | TotalEnvInteracts |         1.2e+05 |
# |            LossPi |        2.15e-09 |
# |             LossV |             539 |
# |       DeltaLossPi |        -0.00394 |
# |        DeltaLossV |           -17.6 |
# |                KL |         0.00831 |
# |    BacktrackIters |               0 |
# |              Time |            27.4 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            80.1 |
# |          StdVVals |            5.54 |
# |          MaxVVals |              86 |
# |          MinVVals |              67 |
# | TotalEnvInteracts |        1.24e+05 |
# |            LossPi |          -1e-08 |
# |             LossV |             569 |
# |       DeltaLossPi |        -0.00623 |
# |        DeltaLossV |           -15.5 |
# |                KL |         0.00923 |
# |    BacktrackIters |               0 |
# |              Time |            28.4 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.2 |
# |          StdVVals |            5.23 |
# |          MaxVVals |            87.5 |
# |          MinVVals |            61.6 |
# | TotalEnvInteracts |        1.28e+05 |
# |            LossPi |       -1.91e-09 |
# |             LossV |             562 |
# |       DeltaLossPi |         -0.0037 |
# |        DeltaLossV |           -10.8 |
# |                KL |         0.00768 |
# |    BacktrackIters |               0 |
# |              Time |            29.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 57 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             493 |
# |          StdEpRet |            18.9 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             443 |
# |             EpLen |             493 |
# |      AverageVVals |            81.7 |
# |          StdVVals |            7.05 |
# |          MaxVVals |            87.2 |
# |          MinVVals |            48.9 |
# | TotalEnvInteracts |        1.32e+05 |
# |            LossPi |       -1.36e-08 |
# |             LossV |             519 |
# |       DeltaLossPi |        -0.00102 |
# |        DeltaLossV |           -13.6 |
# |                KL |         0.00542 |
# |    BacktrackIters |               0 |
# |              Time |            30.2 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            83.3 |
# |          StdVVals |            4.52 |
# |          MaxVVals |            86.4 |
# |          MinVVals |            55.8 |
# | TotalEnvInteracts |        1.36e+05 |
# |            LossPi |        9.54e-09 |
# |             LossV |             636 |
# |       DeltaLossPi |         -0.0037 |
# |        DeltaLossV |           -33.1 |
# |                KL |         0.00879 |
# |    BacktrackIters |               0 |
# |              Time |              31 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            81.9 |
# |          StdVVals |            1.61 |
# |          MaxVVals |            82.7 |
# |          MinVVals |            70.8 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |       -4.05e-09 |
# |             LossV |             595 |
# |       DeltaLossPi |        -0.00279 |
# |        DeltaLossV |           -13.1 |
# |                KL |         0.00719 |
# |    BacktrackIters |               0 |
# |              Time |            31.9 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            77.9 |
# |          StdVVals |               8 |
# |          MaxVVals |              82 |
# |          MinVVals |            39.7 |
# | TotalEnvInteracts |        1.44e+05 |
# |            LossPi |        4.77e-10 |
# |             LossV |             568 |
# |       DeltaLossPi |        -0.00415 |
# |        DeltaLossV |            -134 |
# |                KL |         0.00884 |
# |    BacktrackIters |               0 |
# |              Time |            32.8 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            78.7 |
# |          StdVVals |            8.77 |
# |          MaxVVals |            85.9 |
# |          MinVVals |              46 |
# | TotalEnvInteracts |        1.48e+05 |
# |            LossPi |        6.68e-09 |
# |             LossV |             534 |
# |       DeltaLossPi |        -0.00277 |
# |        DeltaLossV |           -59.9 |
# |                KL |         0.00666 |
# |    BacktrackIters |               0 |
# |              Time |            33.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 202 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             380 |
# |          StdEpRet |            85.6 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             246 |
# |             EpLen |             380 |
# |      AverageVVals |            77.1 |
# |          StdVVals |            13.6 |
# |          MaxVVals |            86.3 |
# |          MinVVals |            31.6 |
# | TotalEnvInteracts |        1.52e+05 |
# |            LossPi |        -1.5e-08 |
# |             LossV |             487 |
# |       DeltaLossPi |        -0.00424 |
# |        DeltaLossV |            -192 |
# |                KL |         0.00756 |
# |    BacktrackIters |               0 |
# |              Time |            34.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 180 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             478 |
# |          StdEpRet |              39 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             407 |
# |             EpLen |             478 |
# |      AverageVVals |            82.3 |
# |          StdVVals |            9.85 |
# |          MaxVVals |            87.3 |
# |          MinVVals |              29 |
# | TotalEnvInteracts |        1.56e+05 |
# |            LossPi |       -5.96e-09 |
# |             LossV |             487 |
# |       DeltaLossPi |        -0.00384 |
# |        DeltaLossV |             -76 |
# |                KL |         0.00789 |
# |    BacktrackIters |               0 |
# |              Time |            35.5 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.9 |
# |          StdVVals |            4.76 |
# |          MaxVVals |            87.5 |
# |          MinVVals |            60.7 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |       -4.77e-09 |
# |             LossV |             595 |
# |       DeltaLossPi |        -0.00484 |
# |        DeltaLossV |           -76.4 |
# |                KL |         0.00849 |
# |    BacktrackIters |               0 |
# |              Time |            36.3 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            81.4 |
# |          StdVVals |            5.51 |
# |          MaxVVals |            88.5 |
# |          MinVVals |            53.8 |
# | TotalEnvInteracts |        1.64e+05 |
# |            LossPi |       -4.77e-10 |
# |             LossV |             568 |
# |       DeltaLossPi |        -0.00536 |
# |        DeltaLossV |           -15.4 |
# |                KL |         0.00851 |
# |    BacktrackIters |               0 |
# |              Time |            37.3 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.6 |
# |          StdVVals |            4.09 |
# |          MaxVVals |            89.1 |
# |          MinVVals |            71.3 |
# | TotalEnvInteracts |        1.68e+05 |
# |            LossPi |        2.86e-09 |
# |             LossV |             569 |
# |       DeltaLossPi |        -0.00347 |
# |        DeltaLossV |           -46.7 |
# |                KL |          0.0085 |
# |    BacktrackIters |               0 |
# |              Time |            38.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 80 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             490 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             420 |
# |             EpLen |             490 |
# |      AverageVVals |            79.7 |
# |          StdVVals |             8.5 |
# |          MaxVVals |            90.1 |
# |          MinVVals |            33.3 |
# | TotalEnvInteracts |        1.72e+05 |
# |            LossPi |        7.87e-09 |
# |             LossV |             537 |
# |       DeltaLossPi |        -0.00372 |
# |        DeltaLossV |           -46.3 |
# |                KL |          0.0094 |
# |    BacktrackIters |               0 |
# |              Time |            39.2 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.6 |
# |          StdVVals |            6.21 |
# |          MaxVVals |            90.1 |
# |          MinVVals |            44.9 |
# | TotalEnvInteracts |        1.76e+05 |
# |            LossPi |               0 |
# |             LossV |             536 |
# |       DeltaLossPi |        -0.00297 |
# |        DeltaLossV |           -68.7 |
# |                KL |         0.00989 |
# |    BacktrackIters |               0 |
# |              Time |              40 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            82.5 |
# |          StdVVals |            7.41 |
# |          MaxVVals |            90.9 |
# |          MinVVals |            54.4 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |       -5.01e-09 |
# |             LossV |             578 |
# |       DeltaLossPi |        -0.00438 |
# |        DeltaLossV |           -50.3 |
# |                KL |         0.00807 |
# |    BacktrackIters |               0 |
# |              Time |            40.9 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            83.7 |
# |          StdVVals |            4.58 |
# |          MaxVVals |            90.1 |
# |          MinVVals |            48.7 |
# | TotalEnvInteracts |        1.84e+05 |
# |            LossPi |        2.62e-09 |
# |             LossV |             581 |
# |       DeltaLossPi |         -0.0061 |
# |        DeltaLossV |           -49.4 |
# |                KL |         0.00772 |
# |    BacktrackIters |               0 |
# |              Time |            41.8 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            78.2 |
# |          StdVVals |            9.35 |
# |          MaxVVals |            85.7 |
# |          MinVVals |            22.4 |
# | TotalEnvInteracts |        1.88e+05 |
# |            LossPi |        3.81e-09 |
# |             LossV |             511 |
# |       DeltaLossPi |        -0.00273 |
# |        DeltaLossV |           -39.3 |
# |                KL |         0.00961 |
# |    BacktrackIters |               0 |
# |              Time |            42.8 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |              73 |
# |          StdVVals |            12.7 |
# |          MaxVVals |            88.3 |
# |          MinVVals |            30.7 |
# | TotalEnvInteracts |        1.92e+05 |
# |            LossPi |        6.91e-09 |
# |             LossV |             565 |
# |       DeltaLossPi |        -0.00346 |
# |        DeltaLossV |            -101 |
# |                KL |         0.00861 |
# |    BacktrackIters |               0 |
# |              Time |            43.6 |
# ---------------------------------------
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            77.7 |
# |          StdVVals |              12 |
# |          MaxVVals |            90.5 |
# |          MinVVals |            33.6 |
# | TotalEnvInteracts |        1.96e+05 |
# |            LossPi |       -4.77e-09 |
# |             LossV |             547 |
# |       DeltaLossPi |         -0.0066 |
# |        DeltaLossV |           -32.3 |
# |                KL |         0.00956 |
# |    BacktrackIters |               0 |
# |              Time |            44.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 392 steps.
# Accepting new params at step 0 of line search.
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             451 |
# |          StdEpRet |            89.6 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             238 |
# |             EpLen |             451 |
# |      AverageVVals |            77.6 |
# |          StdVVals |            11.9 |
# |          MaxVVals |            91.7 |
# |          MinVVals |            26.1 |
# | TotalEnvInteracts |           2e+05 |
# |            LossPi |        7.15e-10 |
# |             LossV |             375 |
# |       DeltaLossPi |        -0.00549 |
# |        DeltaLossV |           -72.2 |
# |                KL |         0.00832 |
# |    BacktrackIters |               0 |
# |              Time |            45.5 |
# ---------------------------------------

# %%
### Start the training process using the custom TRPO implementation

logger_kwargs = setup_logger_kwargs(exp_name=exp_name_custom, data_dir=data_dir)

trainer = TRPOTrainer()
trainer.train_mod(env_fn, ac=MLPActorCritic, ac_kwargs=ac_kwargs, seed=seed,
                  steps_per_epoch=steps_per_epoch, epochs=epochs, gamma=gamma, 
                  delta=delta, surr_obj_min=surr_obj_min, vf_lr=vf_lr, 
                  train_v_iters=train_v_iters, damping_coeff=damping_coeff, 
                  cg_iters=cg_iters, backtrack_iters=backtrack_iters, 
                  backtrack_coeff=backtrack_coeff, lam=lam, max_ep_len=max_ep_len, 
                  logger_kwargs=logger_kwargs, save_freq=save_freq)
# Out:
# /home/sherif/miniconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Warning: Log dir /home/sherif/user/python/DRL/data/trpo/trpo_custom_discrete already exists! Storing info there anyway.
# Logging data to /home/sherif/user/python/DRL/data/trpo/trpo_custom_discrete/progress.txt
# Saving config:
#
# {
#     "ac":	"MLPActorCritic",
#     "ac_kwargs":	{
#         "hidden_acts_actor":	"Tanh",
#         "hidden_acts_critic":	"Tanh",
#         "hidden_sizes_actor":	[
#             64,
#             64
#         ],
#         "hidden_sizes_critic":	[
#             64,
#             64
#         ]
#     },
#     "ac_mod":	{
#         "MLPActorCritic(\n  (actor): MLPActorDiscrete(\n    (net): Sequential(\n      (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n      (activation_1): Tanh()\n      (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n      (activation_2): Tanh()\n      (output): Linear(in_features=64, out_features=2, bias=True)\n    )\n  )\n  (critic): MLPCritic(\n    (net): Sequential(\n      (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n      (activation_1): Tanh()\n      (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n      (activation_2): Tanh()\n      (output): Linear(in_features=64, out_features=1, bias=True)\n    )\n  )\n)":	{
#             "_backward_hooks":	{},
#             "_buffers":	{},
#             "_forward_hooks":	{},
#             "_forward_pre_hooks":	{},
#             "_load_state_dict_pre_hooks":	{},
#             "_modules":	{
#                 "actor":	{
#                     "MLPActorDiscrete(\n  (net): Sequential(\n    (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n    (activation_1): Tanh()\n    (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n    (activation_2): Tanh()\n    (output): Linear(in_features=64, out_features=2, bias=True)\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "net":	{
#                                 "Sequential(\n  (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n  (activation_1): Tanh()\n  (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n  (activation_2): Tanh()\n  (output): Linear(in_features=64, out_features=2, bias=True)\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "activation_1":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         },
#                                         "activation_2":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         },
#                                         "hidden_1":	{
#                                             "Linear(in_features=4, out_features=64, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.4956,  0.2257, -0.2401, -0.3337, -0.2881,  0.2875,  0.2648,  0.3838,\n         0.1814, -0.1670, -0.1397,  0.1477,  0.4110,  0.1359, -0.2366, -0.2350,\n        -0.4727,  0.1080, -0.2806, -0.4458,  0.4384, -0.3247, -0.0569,  0.1432,\n         0.0159, -0.3364, -0.4042,  0.3985,  0.0814,  0.4148, -0.1676,  0.1473,\n        -0.1143, -0.0222, -0.3045,  0.1691,  0.1581, -0.0103, -0.1125, -0.3082,\n         0.3458, -0.3722,  0.2048, -0.1681, -0.2412,  0.0898, -0.2597,  0.1152,\n         0.0982, -0.3712,  0.0832,  0.2130,  0.1979, -0.0629, -0.4099, -0.0771,\n         0.1737, -0.1824,  0.1898,  0.3330, -0.2611,  0.0049,  0.2067,  0.0392],\n       requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-0.0037,  0.2682, -0.4115, -0.3680],\n        [-0.1926,  0.1341, -0.0099,  0.3964],\n        [-0.0444,  0.1323, -0.1511, -0.0983],\n        [-0.4777, -0.3311, -0.2061,  0.0185],\n        [ 0.1977,  0.3000, -0.3390, -0.2177],\n        [ 0.1816,  0.4152, -0.1029,  0.3742],\n        [-0.0806,  0.0529,  0.4527, -0.4638],\n        [-0.3148, -0.1266, -0.1949,  0.4320],\n        [-0.3241, -0.2302, -0.3493, -0.4683],\n        [-0.2919,  0.4298,  0.2231,  0.2423],\n        [ 0.0263, -0.2563,  0.0846, -0.4668],\n        [-0.3613, -0.2578,  0.3155,  0.2932],\n        [-0.2217, -0.0180,  0.3198,  0.4971],\n        [ 0.1984,  0.0675,  0.3352, -0.2944],\n        [ 0.0932, -0.3877, -0.3465, -0.2583],\n        [ 0.2262,  0.2011, -0.2962,  0.1511],\n        [ 0.2745, -0.0631,  0.0191,  0.1159],\n        [ 0.3102,  0.4801, -0.3853, -0.1832],\n        [ 0.1965,  0.4143,  0.4351,  0.4412],\n        [ 0.0995, -0.4348,  0.0460, -0.3128],\n        [-0.4660,  0.4442,  0.3802, -0.4988],\n        [ 0.0936, -0.0842, -0.0823, -0.2289],\n        [ 0.1923, -0.2962,  0.1833,  0.2529],\n        [ 0.3579,  0.1870, -0.4949, -0.3243],\n        [ 0.2497,  0.1047, -0.3900, -0.2879],\n        [ 0.4704,  0.3369, -0.2180, -0.1258],\n        [-0.4763, -0.0090, -0.3765, -0.3857],\n        [-0.0275,  0.0751, -0.2048,  0.2967],\n        [-0.3043,  0.4537,  0.3426, -0.4216],\n        [-0.1244,  0.0226,  0.0730,  0.1186],\n        [ 0.1962,  0.0300, -0.2440,  0.2366],\n        [-0.4796, -0.2964, -0.1252, -0.2436],\n        [-0.1749, -0.4098, -0.1064,  0.1069],\n        [-0.3257, -0.0257,  0.3579, -0.0514],\n        [ 0.0139, -0.0431,  0.1012,  0.3179],\n        [ 0.4736,  0.3175,  0.4747, -0.0362],\n        [-0.4492, -0.2370,  0.3405, -0.0032],\n        [-0.2485, -0.3832, -0.4679, -0.4220],\n        [-0.1014,  0.2742,  0.2703, -0.4822],\n        [ 0.3119, -0.3913, -0.1057, -0.2027],\n        [-0.0963, -0.0982, -0.4487, -0.4317],\n        [-0.0782,  0.0065, -0.2271,  0.1883],\n        [-0.4500, -0.0337,  0.4397, -0.2039],\n        [ 0.4515,  0.1811, -0.4512,  0.3163],\n        [-0.0577, -0.2232,  0.3998, -0.4040],\n        [ 0.0537, -0.1047,  0.3571,  0.1396],\n        [ 0.2403,  0.1766, -0.1202, -0.1052],\n        [-0.4120,  0.2709,  0.3970,  0.3421],\n        [-0.3527,  0.0223, -0.3525, -0.2752],\n        [-0.2914,  0.1709, -0.2980, -0.0109],\n        [ 0.0210,  0.3223, -0.3780, -0.3433],\n        [-0.2903,  0.3500, -0.1797,  0.4217],\n        [ 0.1808,  0.0633, -0.0037, -0.0988],\n        [ 0.0627, -0.1142, -0.0035,  0.0638],\n        [-0.3911, -0.2621,  0.4037, -0.4058],\n        [-0.0359,  0.4946,  0.1806,  0.0142],\n        [-0.4333,  0.2477, -0.3561, -0.1419],\n        [-0.1678, -0.0740,  0.0055,  0.4124],\n        [ 0.0624,  0.4478,  0.3059, -0.3161],\n        [ 0.2243, -0.3534, -0.2119,  0.1471],\n        [ 0.1651,  0.3751, -0.1610,  0.0008],\n        [ 0.2574, -0.4835,  0.3615, -0.4135],\n        [ 0.0069, -0.0850, -0.2633,  0.0661],\n        [ 0.4135, -0.1462, -0.2968, -0.1849]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	4,
#                                                 "out_features":	64,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "hidden_2":	{
#                                             "Linear(in_features=64, out_features=64, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ 0.0958,  0.0990, -0.0344, -0.0726, -0.0555, -0.0854, -0.0322, -0.1129,\n         0.0668, -0.1176, -0.0778,  0.0839, -0.0935,  0.0299,  0.0936,  0.1232,\n         0.0632, -0.0335,  0.0714, -0.0041, -0.0385,  0.0004,  0.0280,  0.0838,\n         0.0525,  0.0597,  0.0187, -0.0063,  0.0525,  0.0301, -0.1196,  0.0202,\n        -0.0555, -0.0663,  0.0483,  0.0256,  0.0212, -0.0593,  0.0578,  0.1173,\n         0.0153,  0.0514, -0.1097,  0.0743,  0.0434,  0.0563,  0.0521, -0.0329,\n        -0.0075,  0.1209,  0.0915, -0.0896,  0.0992,  0.1244,  0.0164, -0.0975,\n         0.0242, -0.0252,  0.0899, -0.1201,  0.0320, -0.0015,  0.0098,  0.0860],\n       requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0104,  0.0156, -0.0983,  ..., -0.0320,  0.0550,  0.1114],\n        [ 0.0414,  0.1250,  0.0648,  ...,  0.1039, -0.0500,  0.0366],\n        [ 0.0057, -0.1127,  0.1037,  ...,  0.0418, -0.0360,  0.0773],\n        ...,\n        [ 0.0551,  0.0994,  0.1193,  ..., -0.0264,  0.0643,  0.0257],\n        [-0.1003,  0.0246,  0.0806,  ..., -0.0367,  0.0546,  0.0245],\n        [-0.0631,  0.0218,  0.1150,  ..., -0.0944, -0.0861,  0.0344]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	64,
#                                                 "out_features":	64,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "output":	{
#                                             "Linear(in_features=64, out_features=2, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([0.1120, 0.1010], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 2.2581e-03, -1.0064e-01, -7.2917e-02, -5.0050e-02,  1.3331e-02,\n          4.8237e-02, -2.3332e-02, -4.9335e-02,  5.4851e-02, -1.2154e-01,\n          8.7348e-02, -1.4531e-02,  8.6979e-02,  9.4452e-02,  1.3353e-02,\n          3.9541e-02, -7.0701e-02,  8.9561e-02,  7.3162e-02, -1.9632e-02,\n          4.8722e-02, -7.0017e-03,  9.7661e-02,  5.1456e-02,  9.1131e-02,\n         -1.1362e-01,  1.2179e-01,  4.6573e-02,  6.0773e-02,  2.7854e-02,\n          8.2098e-02,  1.1768e-01, -1.0649e-02, -1.0257e-01,  1.1478e-01,\n         -2.6361e-02, -6.0285e-02,  7.6948e-02,  6.9760e-02,  1.6735e-02,\n         -7.8465e-03, -2.3913e-02,  1.1461e-01,  7.6161e-02,  7.4442e-02,\n          7.9710e-02, -6.5420e-02,  2.6099e-02, -1.0814e-01,  7.2622e-02,\n         -1.2390e-01, -1.2493e-01, -1.2356e-01,  7.7083e-02,  1.3009e-02,\n          2.8425e-04,  1.9882e-02, -4.7306e-02, -3.7958e-02, -8.4199e-02,\n         -3.0527e-02, -7.6917e-02,  3.2888e-03,  9.8213e-02],\n        [-1.0334e-01,  6.1471e-02, -9.2975e-02, -5.1790e-02,  2.4443e-02,\n          2.1508e-02,  1.0251e-01, -4.6760e-05, -4.7609e-02, -5.1696e-02,\n          3.6647e-03, -9.3729e-02, -9.8007e-02, -5.3483e-02,  3.2110e-03,\n         -8.4418e-02, -7.1354e-02,  8.9249e-02,  1.1551e-01, -3.9154e-02,\n         -1.0724e-01, -4.7857e-02,  5.0450e-02,  4.0568e-02, -3.8750e-02,\n         -1.1009e-01, -3.7586e-02, -2.7949e-02,  7.1983e-02, -6.1984e-02,\n          7.5021e-02,  1.7340e-02, -2.0950e-02, -1.1140e-01,  1.2341e-01,\n         -2.2290e-02,  7.8650e-02, -6.4659e-02, -1.2173e-01, -9.9638e-02,\n         -6.4061e-02, -3.9809e-02, -1.7652e-02,  1.0425e-01, -1.1528e-01,\n          6.2390e-02,  1.0518e-01,  8.0453e-04, -7.7955e-02,  3.9980e-03,\n          2.9655e-02,  5.5308e-02, -3.7996e-02, -4.2896e-02, -5.8971e-02,\n         -1.2090e-01,  4.3901e-02, -9.4502e-02, -6.0050e-02, -1.2863e-03,\n          9.6363e-02,  1.1114e-01, -9.0920e-02,  1.0841e-01]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	64,
#                                                 "out_features":	2,
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "obs_dim":	4,
#                         "pi":	{
#                             "Categorical(logits: torch.Size([2]))":	{
#                                 "_batch_shape":	[],
#                                 "_event_shape":	[],
#                                 "_num_events":	2,
#                                 "_param":	"tensor([-3.3769, -0.0348])",
#                                 "logits":	"tensor([-3.3769, -0.0348])"
#                             }
#                         },
#                         "pi_prev":	{
#                             "Categorical(logits: torch.Size([2]))":	{
#                                 "_batch_shape":	[],
#                                 "_event_shape":	[],
#                                 "_num_events":	2,
#                                 "_param":	"tensor([-3.3769, -0.0348])",
#                                 "logits":	"tensor([-3.3769, -0.0348])"
#                             }
#                         },
#                         "training":	true
#                     }
#                 },
#                 "critic":	{
#                     "MLPCritic(\n  (net): Sequential(\n    (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n    (activation_1): Tanh()\n    (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n    (activation_2): Tanh()\n    (output): Linear(in_features=64, out_features=1, bias=True)\n  )\n)":	{
#                         "_backward_hooks":	{},
#                         "_buffers":	{},
#                         "_forward_hooks":	{},
#                         "_forward_pre_hooks":	{},
#                         "_load_state_dict_pre_hooks":	{},
#                         "_modules":	{
#                             "net":	{
#                                 "Sequential(\n  (hidden_1): Linear(in_features=4, out_features=64, bias=True)\n  (activation_1): Tanh()\n  (hidden_2): Linear(in_features=64, out_features=64, bias=True)\n  (activation_2): Tanh()\n  (output): Linear(in_features=64, out_features=1, bias=True)\n)":	{
#                                     "_backward_hooks":	{},
#                                     "_buffers":	{},
#                                     "_forward_hooks":	{},
#                                     "_forward_pre_hooks":	{},
#                                     "_load_state_dict_pre_hooks":	{},
#                                     "_modules":	{
#                                         "activation_1":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         },
#                                         "activation_2":	{
#                                             "Tanh()":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{},
#                                                 "_state_dict_hooks":	{},
#                                                 "training":	true
#                                             }
#                                         },
#                                         "hidden_1":	{
#                                             "Linear(in_features=4, out_features=64, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ 0.1724,  0.3257,  0.3419,  0.2986,  0.2796,  0.1353,  0.2581, -0.3431,\n        -0.3236,  0.1345,  0.0778, -0.4396, -0.3642, -0.3980,  0.3971,  0.3269,\n        -0.2632,  0.0754, -0.1150,  0.4347, -0.4529, -0.3648, -0.4163,  0.2910,\n        -0.2499,  0.2978,  0.1690, -0.2444, -0.1347, -0.2023,  0.2206, -0.2005,\n         0.1697,  0.0357, -0.3993, -0.3143, -0.3467,  0.2620,  0.1083, -0.0126,\n        -0.2977, -0.4954, -0.1769, -0.3827, -0.4973, -0.4769, -0.3266, -0.4861,\n         0.1559,  0.1871,  0.2015, -0.4977,  0.3092,  0.0975,  0.2557, -0.1229,\n         0.2401, -0.4742,  0.1703,  0.3965,  0.2102, -0.4713, -0.1404, -0.0621],\n       requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[-0.2635,  0.0094, -0.3543, -0.1646],\n        [ 0.4031,  0.2328,  0.4354,  0.0038],\n        [-0.2550,  0.3309,  0.0369,  0.0842],\n        [-0.2118,  0.2054, -0.3693,  0.3990],\n        [ 0.4374,  0.1804,  0.3894,  0.3035],\n        [-0.1910, -0.4337,  0.0658,  0.3139],\n        [-0.0512,  0.0421,  0.3706,  0.2064],\n        [ 0.3738,  0.0734,  0.0560, -0.1196],\n        [-0.0844, -0.2657,  0.3343,  0.4560],\n        [ 0.1856,  0.0142, -0.1651, -0.4937],\n        [-0.0926, -0.3550, -0.3691, -0.0990],\n        [-0.0984,  0.1009, -0.3624,  0.3593],\n        [-0.4552, -0.2368, -0.1898,  0.0308],\n        [ 0.2067, -0.1318,  0.0780, -0.1184],\n        [-0.1967, -0.0699,  0.1007, -0.4857],\n        [-0.3480,  0.3906,  0.2261, -0.0134],\n        [ 0.0158,  0.0690,  0.1162, -0.3414],\n        [-0.1363, -0.4589, -0.3931, -0.0941],\n        [-0.0660,  0.3911,  0.0861, -0.0811],\n        [-0.0139,  0.2792, -0.1515, -0.0935],\n        [-0.1003, -0.4032, -0.0699, -0.4622],\n        [-0.2688, -0.3183,  0.3725, -0.4606],\n        [ 0.4818,  0.1875, -0.3379,  0.4142],\n        [-0.1102, -0.4235, -0.0694,  0.2471],\n        [-0.4861, -0.0375,  0.2034, -0.1949],\n        [ 0.0455, -0.1960, -0.3354,  0.3916],\n        [-0.3550, -0.0059,  0.1665, -0.2794],\n        [ 0.2414, -0.4152,  0.4775,  0.2227],\n        [-0.0708, -0.4159,  0.0154,  0.1774],\n        [-0.2716, -0.0630, -0.4983, -0.4999],\n        [-0.0543,  0.4184, -0.0235,  0.1568],\n        [-0.1999, -0.1633, -0.0550, -0.2528],\n        [ 0.3060,  0.3118, -0.3887,  0.1534],\n        [-0.2066, -0.2875, -0.0610, -0.1551],\n        [-0.2847,  0.0737,  0.2854, -0.0772],\n        [-0.0350,  0.0376, -0.2149,  0.2647],\n        [ 0.4613, -0.0457,  0.0340,  0.4029],\n        [ 0.4095, -0.3720, -0.2316, -0.4905],\n        [ 0.3062,  0.3903, -0.1820,  0.1604],\n        [ 0.1211, -0.4302,  0.1997,  0.2453],\n        [ 0.0110,  0.0513,  0.1162,  0.3602],\n        [ 0.4418,  0.0719,  0.2131, -0.1308],\n        [ 0.2981, -0.1967, -0.4121,  0.2346],\n        [ 0.1854,  0.1101,  0.2127,  0.0595],\n        [ 0.1702,  0.2037, -0.2697, -0.0268],\n        [ 0.0754, -0.0759, -0.4204,  0.0474],\n        [ 0.3056, -0.2674,  0.4909,  0.1140],\n        [ 0.2127, -0.1931, -0.4090, -0.1861],\n        [ 0.0153, -0.2278,  0.4453, -0.3200],\n        [-0.3368, -0.1774,  0.4486, -0.2286],\n        [ 0.4626,  0.2403, -0.0760,  0.2586],\n        [ 0.2377, -0.2545, -0.1029,  0.4843],\n        [ 0.2867, -0.2442, -0.1344,  0.2802],\n        [ 0.2538,  0.0396, -0.3217, -0.3688],\n        [-0.1055,  0.1838, -0.0533, -0.4180],\n        [-0.1225,  0.4991, -0.4133, -0.3880],\n        [ 0.3143,  0.4975, -0.4810, -0.4522],\n        [-0.1563,  0.4985, -0.2838,  0.0427],\n        [ 0.4082, -0.1770, -0.1533, -0.3356],\n        [ 0.0192,  0.4667,  0.2045,  0.3514],\n        [-0.0331, -0.0794, -0.0893,  0.2852],\n        [-0.0656, -0.4271, -0.1756,  0.1957],\n        [ 0.4875, -0.0909, -0.4353, -0.3682],\n        [-0.3934,  0.2016,  0.3686,  0.1479]], requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	4,
#                                                 "out_features":	64,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "hidden_2":	{
#                                             "Linear(in_features=64, out_features=64, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([ 0.0640, -0.0098, -0.0402,  0.0309, -0.0040,  0.0106, -0.0268, -0.0012,\n        -0.0301,  0.1051, -0.0848, -0.0953, -0.0243,  0.0093,  0.0822,  0.0346,\n        -0.0021, -0.1183, -0.0590,  0.0326, -0.0400, -0.0765,  0.0315,  0.0892,\n         0.0154,  0.0936,  0.1078,  0.0031,  0.1250,  0.0413,  0.0412,  0.0453,\n        -0.1157,  0.0509,  0.1050,  0.0233,  0.0075, -0.0214, -0.0982,  0.0159,\n         0.0504,  0.0477,  0.1135, -0.0748,  0.1101, -0.0280, -0.0365, -0.0632,\n        -0.0836,  0.0268, -0.0266,  0.0230, -0.1217, -0.0405,  0.0642, -0.0608,\n         0.1155, -0.0830, -0.0720,  0.0831,  0.1077,  0.0553,  0.0665, -0.0886],\n       requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0655, -0.0473,  0.0180,  ..., -0.0303, -0.1145, -0.0531],\n        [ 0.0042, -0.0967,  0.1097,  ...,  0.1168,  0.1119,  0.1016],\n        [ 0.0327, -0.0105,  0.0048,  ...,  0.1141, -0.0377, -0.1117],\n        ...,\n        [-0.0671, -0.0120,  0.0362,  ..., -0.0740, -0.0183, -0.0393],\n        [ 0.0631, -0.0296, -0.1065,  ..., -0.0837,  0.0330,  0.1110],\n        [ 0.1137,  0.0415,  0.0457,  ...,  0.0213, -0.0479, -0.0042]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	64,
#                                                 "out_features":	64,
#                                                 "training":	true
#                                             }
#                                         },
#                                         "output":	{
#                                             "Linear(in_features=64, out_features=1, bias=True)":	{
#                                                 "_backward_hooks":	{},
#                                                 "_buffers":	{},
#                                                 "_forward_hooks":	{},
#                                                 "_forward_pre_hooks":	{},
#                                                 "_load_state_dict_pre_hooks":	{},
#                                                 "_modules":	{},
#                                                 "_parameters":	{
#                                                     "bias":	"Parameter containing:\ntensor([-0.0191], requires_grad=True)",
#                                                     "weight":	"Parameter containing:\ntensor([[ 0.0236, -0.0117, -0.0588,  0.0266,  0.0507, -0.0865, -0.0153,  0.0327,\n          0.1210, -0.1007,  0.1103, -0.0121,  0.0278, -0.1078, -0.1100, -0.0640,\n         -0.0092,  0.0238,  0.1118, -0.0207,  0.0862, -0.1049,  0.0700, -0.1080,\n         -0.1186,  0.0750, -0.0816, -0.0691, -0.0738, -0.0345,  0.0610,  0.0626,\n         -0.0941,  0.0101, -0.1034, -0.1061, -0.0319, -0.0107,  0.0624,  0.0543,\n          0.0312,  0.0954, -0.0143, -0.0111,  0.1208,  0.0086,  0.0851, -0.0623,\n          0.0802,  0.0747,  0.0983, -0.0741, -0.1192,  0.0222, -0.0159,  0.1183,\n         -0.0418, -0.0548,  0.0195, -0.0999, -0.1027,  0.0805,  0.0286,  0.0246]],\n       requires_grad=True)"
#                                                 },
#                                                 "_state_dict_hooks":	{},
#                                                 "in_features":	64,
#                                                 "out_features":	1,
#                                                 "training":	true
#                                             }
#                                         }
#                                     },
#                                     "_parameters":	{},
#                                     "_state_dict_hooks":	{},
#                                     "training":	true
#                                 }
#                             }
#                         },
#                         "_parameters":	{},
#                         "_state_dict_hooks":	{},
#                         "obs_dim":	4,
#                         "training":	true
#                     }
#                 }
#             },
#             "_parameters":	{},
#             "_state_dict_hooks":	{},
#             "training":	true
#         }
#     },
#     "backtrack_coeff":	0.8,
#     "backtrack_iters":	10,
#     "cg_iters":	10,
#     "damping_coeff":	0.1,
#     "delta":	0.01,
#     "env":	{
#         "<TimeLimit<CartPoleEnv<CartPole-v1>>>":	{
#             "_elapsed_steps":	null,
#             "_max_episode_steps":	500,
#             "action_space":	{
#                 "Discrete(2)":	{
#                     "dtype":	"int64",
#                     "n":	2,
#                     "np_random":	"RandomState(MT19937)",
#                     "shape":	[]
#                 }
#             },
#             "env":	{
#                 "<CartPoleEnv<CartPole-v1>>":	{
#                     "action_space":	{
#                         "Discrete(2)":	{
#                             "dtype":	"int64",
#                             "n":	2,
#                             "np_random":	"RandomState(MT19937)",
#                             "shape":	[]
#                         }
#                     },
#                     "force_mag":	10.0,
#                     "gravity":	9.8,
#                     "kinematics_integrator":	"euler",
#                     "length":	0.5,
#                     "masscart":	1.0,
#                     "masspole":	0.1,
#                     "np_random":	"RandomState(MT19937)",
#                     "observation_space":	{
#                         "Box(4,)":	{
#                             "bounded_above":	"[ True  True  True  True]",
#                             "bounded_below":	"[ True  True  True  True]",
#                             "dtype":	"float32",
#                             "high":	"[4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]",
#                             "low":	"[-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]",
#                             "np_random":	"RandomState(MT19937)",
#                             "shape":	[
#                                 4
#                             ]
#                         }
#                     },
#                     "polemass_length":	0.05,
#                     "spec":	{
#                         "EnvSpec(CartPole-v1)":	{
#                             "_env_name":	"CartPole",
#                             "_kwargs":	{},
#                             "entry_point":	"gym.envs.classic_control:CartPoleEnv",
#                             "id":	"CartPole-v1",
#                             "max_episode_steps":	500,
#                             "nondeterministic":	false,
#                             "reward_threshold":	475.0,
#                             "tags":	{
#                                 "wrapper_config.TimeLimit.max_episode_steps":	500
#                             }
#                         }
#                     },
#                     "state":	null,
#                     "steps_beyond_done":	null,
#                     "tau":	0.02,
#                     "theta_threshold_radians":	0.20943951023931953,
#                     "total_mass":	1.1,
#                     "viewer":	null,
#                     "x_threshold":	2.4
#                 }
#             },
#             "metadata":	{
#                 "render.modes":	[
#                     "human",
#                     "rgb_array"
#                 ],
#                 "video.frames_per_second":	50
#             },
#             "observation_space":	{
#                 "Box(4,)":	{
#                     "bounded_above":	"[ True  True  True  True]",
#                     "bounded_below":	"[ True  True  True  True]",
#                     "dtype":	"float32",
#                     "high":	"[4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]",
#                     "low":	"[-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]",
#                     "np_random":	"RandomState(MT19937)",
#                     "shape":	[
#                         4
#                     ]
#                 }
#             },
#             "reward_range":	[
#                 -Infinity,
#                 Infinity
#             ]
#         }
#     },
#     "env_fn":	"<function <lambda> at 0x7017033398c8>",
#     "epochs":	50,
#     "exp_name":	"trpo_custom_discrete",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "local_steps_per_epoch":	4000,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7017033ebef0>":	{
#             "epoch_dict":	{},
#             "exp_name":	"trpo_custom_discrete",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/home/sherif/user/python/DRL/data/trpo/trpo_custom_discrete",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/home/sherif/user/python/DRL/data/trpo/trpo_custom_discrete/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"trpo_custom_discrete",
#         "output_dir":	"/home/sherif/user/python/DRL/data/trpo/trpo_custom_discrete"
#     },
#     "max_ep_len":	1000,
#     "save_freq":	10,
#     "seed":	0,
#     "self":	"<train.TRPOTrainer object at 0x70170331ae80>",
#     "steps_per_epoch":	4000,
#     "train_v_iters":	80,
#     "vf_lr":	0.001
# }
# Model 0 saved successfully
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            21.2 |
# |          StdEpRet |            10.7 |
# |          MaxEpRet |              77 |
# |          MinEpRet |               8 |
# |             EpLen |            21.2 |
# |      AverageVVals |           -0.14 |
# |          StdVVals |          0.0455 |
# |          MaxVVals |          0.0163 |
# |          MinVVals |          -0.233 |
# | TotalEnvInteracts |           4e+03 |
# |            LossPi |          0.0198 |
# |             LossV |             102 |
# |       DeltaLossPi |         -0.0198 |
# |        DeltaLossV |            -137 |
# |                KL |         0.00875 |
# |    BacktrackIters |               0 |
# |              Time |            7.52 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            27.8 |
# |          StdEpRet |            16.2 |
# |          MaxEpRet |             115 |
# |          MinEpRet |               9 |
# |             EpLen |            27.8 |
# |      AverageVVals |            7.97 |
# |          StdVVals |           0.246 |
# |          MaxVVals |            8.23 |
# |          MinVVals |            5.65 |
# | TotalEnvInteracts |           8e+03 |
# |            LossPi |          0.0184 |
# |             LossV |             153 |
# |       DeltaLossPi |         0.00144 |
# |        DeltaLossV |           -65.4 |
# |                KL |         0.00842 |
# |    BacktrackIters |               0 |
# |              Time |              15 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |              32 |
# |          StdEpRet |            17.2 |
# |          MaxEpRet |              82 |
# |          MinEpRet |               9 |
# |             EpLen |              32 |
# |      AverageVVals |            13.9 |
# |          StdVVals |          0.0566 |
# |          MaxVVals |              14 |
# |          MinVVals |            13.4 |
# | TotalEnvInteracts |         1.2e+04 |
# |            LossPi |          0.0201 |
# |             LossV |             151 |
# |       DeltaLossPi |        -0.00173 |
# |        DeltaLossV |           -17.6 |
# |                KL |         0.00867 |
# |    BacktrackIters |               0 |
# |              Time |            22.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            48.2 |
# |          StdEpRet |            33.2 |
# |          MaxEpRet |             160 |
# |          MinEpRet |              14 |
# |             EpLen |            48.2 |
# |      AverageVVals |            17.1 |
# |          StdVVals |           0.111 |
# |          MaxVVals |            17.2 |
# |          MinVVals |            15.1 |
# | TotalEnvInteracts |         1.6e+04 |
# |            LossPi |          0.0211 |
# |             LossV |             384 |
# |       DeltaLossPi |        -0.00103 |
# |        DeltaLossV |           -94.4 |
# |                KL |         0.00823 |
# |    BacktrackIters |               0 |
# |              Time |            29.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            72.7 |
# |          StdEpRet |            44.3 |
# |          MaxEpRet |             210 |
# |          MinEpRet |              12 |
# |             EpLen |            72.7 |
# |      AverageVVals |            23.9 |
# |          StdVVals |          0.0304 |
# |          MaxVVals |              24 |
# |          MinVVals |            23.6 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |          0.0208 |
# |             LossV |             485 |
# |       DeltaLossPi |        0.000326 |
# |        DeltaLossV |            -117 |
# |                KL |         0.00689 |
# |    BacktrackIters |               0 |
# |              Time |            37.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |             114 |
# |          StdEpRet |            59.3 |
# |          MaxEpRet |             226 |
# |          MinEpRet |              18 |
# |             EpLen |             114 |
# |      AverageVVals |              31 |
# |          StdVVals |          0.0127 |
# |          MaxVVals |              31 |
# |          MinVVals |            30.9 |
# | TotalEnvInteracts |         2.4e+04 |
# |            LossPi |          0.0186 |
# |             LossV |             650 |
# |       DeltaLossPi |         0.00225 |
# |        DeltaLossV |            -184 |
# |                KL |         0.00774 |
# |    BacktrackIters |               0 |
# |              Time |            44.7 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |             200 |
# |          StdEpRet |            59.2 |
# |          MaxEpRet |             352 |
# |          MinEpRet |              89 |
# |             EpLen |             200 |
# |      AverageVVals |            39.1 |
# |          StdVVals |         0.00429 |
# |          MaxVVals |            39.1 |
# |          MinVVals |            39.1 |
# | TotalEnvInteracts |         2.8e+04 |
# |            LossPi |          0.0438 |
# |             LossV |             750 |
# |       DeltaLossPi |         -0.0252 |
# |        DeltaLossV |            -270 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |            52.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             190 |
# |          StdEpRet |            77.5 |
# |          MaxEpRet |             374 |
# |          MinEpRet |              58 |
# |             EpLen |             190 |
# |      AverageVVals |              48 |
# |          StdVVals |         0.00596 |
# |          MaxVVals |              48 |
# |          MinVVals |            47.9 |
# | TotalEnvInteracts |         3.2e+04 |
# |            LossPi |          0.0102 |
# |             LossV |             688 |
# |       DeltaLossPi |          0.0336 |
# |        DeltaLossV |             -74 |
# |                KL |         0.00785 |
# |    BacktrackIters |               0 |
# |              Time |            59.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             222 |
# |          StdEpRet |            92.2 |
# |          MaxEpRet |             418 |
# |          MinEpRet |              80 |
# |             EpLen |             222 |
# |      AverageVVals |            52.7 |
# |          StdVVals |          0.0016 |
# |          MaxVVals |            52.7 |
# |          MinVVals |            52.7 |
# | TotalEnvInteracts |         3.6e+04 |
# |            LossPi |         0.00782 |
# |             LossV |             719 |
# |       DeltaLossPi |         0.00239 |
# |        DeltaLossV |           -71.7 |
# |                KL |         0.00567 |
# |    BacktrackIters |               0 |
# |              Time |            66.9 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             308 |
# |          StdEpRet |             115 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             147 |
# |             EpLen |             308 |
# |      AverageVVals |            57.2 |
# |          StdVVals |         0.00195 |
# |          MaxVVals |            57.2 |
# |          MinVVals |            57.2 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |         0.00593 |
# |             LossV |             747 |
# |       DeltaLossPi |         0.00189 |
# |        DeltaLossV |            -139 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |            74.2 |
# ---------------------------------------
# Model 10 saved successfully
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             308 |
# |          StdEpRet |            95.8 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             176 |
# |             EpLen |             308 |
# |      AverageVVals |            63.4 |
# |          StdVVals |         0.00509 |
# |          MaxVVals |            63.4 |
# |          MinVVals |            63.3 |
# | TotalEnvInteracts |         4.4e+04 |
# |            LossPi |          0.0242 |
# |             LossV |             685 |
# |       DeltaLossPi |         -0.0182 |
# |        DeltaLossV |           -45.2 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |            81.6 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             235 |
# |          StdEpRet |              76 |
# |          MaxEpRet |             437 |
# |          MinEpRet |             123 |
# |             EpLen |             235 |
# |      AverageVVals |            67.1 |
# |          StdVVals |         0.00153 |
# |          MaxVVals |            67.1 |
# |          MinVVals |              67 |
# | TotalEnvInteracts |         4.8e+04 |
# |            LossPi |          0.0351 |
# |             LossV |             687 |
# |       DeltaLossPi |         -0.0109 |
# |        DeltaLossV |           -3.86 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |            89.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             267 |
# |          StdEpRet |             116 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             135 |
# |             EpLen |             267 |
# |      AverageVVals |            66.1 |
# |          StdVVals |          0.0296 |
# |          MaxVVals |            66.1 |
# |          MinVVals |            65.9 |
# | TotalEnvInteracts |         5.2e+04 |
# |            LossPi |          0.0131 |
# |             LossV |             714 |
# |       DeltaLossPi |           0.022 |
# |        DeltaLossV |           -3.86 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |            96.5 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             222 |
# |          StdEpRet |            62.7 |
# |          MaxEpRet |             353 |
# |          MinEpRet |             123 |
# |             EpLen |             222 |
# |      AverageVVals |            67.2 |
# |          StdVVals |         0.00222 |
# |          MaxVVals |            67.2 |
# |          MinVVals |            67.1 |
# | TotalEnvInteracts |         5.6e+04 |
# |            LossPi |          0.0101 |
# |             LossV |             670 |
# |       DeltaLossPi |           0.003 |
# |        DeltaLossV |           -14.8 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             104 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             267 |
# |          StdEpRet |            84.9 |
# |          MaxEpRet |             432 |
# |          MinEpRet |             127 |
# |             EpLen |             267 |
# |      AverageVVals |              65 |
# |          StdVVals |           0.419 |
# |          MaxVVals |            65.1 |
# |          MinVVals |            60.5 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |          0.0849 |
# |             LossV |             668 |
# |       DeltaLossPi |         -0.0748 |
# |        DeltaLossV |           -4.73 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             222 |
# |          StdEpRet |            99.3 |
# |          MaxEpRet |             498 |
# |          MinEpRet |              62 |
# |             EpLen |             222 |
# |      AverageVVals |            66.2 |
# |          StdVVals |         0.00992 |
# |          MaxVVals |            66.2 |
# |          MinVVals |            66.1 |
# | TotalEnvInteracts |         6.4e+04 |
# |            LossPi |          0.0076 |
# |             LossV |             693 |
# |       DeltaLossPi |          0.0773 |
# |        DeltaLossV |            -7.1 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             119 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             235 |
# |          StdEpRet |            74.8 |
# |          MaxEpRet |             409 |
# |          MinEpRet |              72 |
# |             EpLen |             235 |
# |      AverageVVals |            64.7 |
# |          StdVVals |          0.0346 |
# |          MaxVVals |            64.7 |
# |          MinVVals |            64.4 |
# | TotalEnvInteracts |         6.8e+04 |
# |            LossPi |          0.0357 |
# |             LossV |             656 |
# |       DeltaLossPi |         -0.0282 |
# |        DeltaLossV |          -0.454 |
# |                KL |               0 |
# ...
# |          StdEpRet |             110 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             126 |
# |             EpLen |             400 |
# |      AverageVVals |            79.5 |
# |          StdVVals |         0.00317 |
# |          MaxVVals |            79.5 |
# |          MinVVals |            79.5 |
# | TotalEnvInteracts |        1.24e+05 |
# |            LossPi |           0.029 |
# |             LossV |             629 |
# |       DeltaLossPi |         -0.0268 |
# |        DeltaLossV |           -1.53 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             230 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             444 |
# |          StdEpRet |             125 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             102 |
# |             EpLen |             444 |
# |      AverageVVals |            78.6 |
# |          StdVVals |         0.00354 |
# |          MaxVVals |            78.6 |
# |          MinVVals |            78.5 |
# | TotalEnvInteracts |        1.28e+05 |
# |            LossPi |           0.116 |
# |             LossV |             591 |
# |       DeltaLossPi |         -0.0874 |
# |        DeltaLossV |           -1.93 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             237 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             400 |
# |          StdEpRet |            93.6 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             243 |
# |             EpLen |             400 |
# |      AverageVVals |            79.7 |
# |          StdVVals |         0.00486 |
# |          MaxVVals |            79.7 |
# |          MinVVals |            79.6 |
# | TotalEnvInteracts |        1.32e+05 |
# |            LossPi |         0.00976 |
# |             LossV |             622 |
# |       DeltaLossPi |           0.107 |
# |        DeltaLossV |           -3.02 |
# |                KL |         0.00811 |
# |    BacktrackIters |               0 |
# |              Time |             245 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             444 |
# |          StdEpRet |             142 |
# |          MaxEpRet |             500 |
# |          MinEpRet |              45 |
# |             EpLen |             444 |
# |      AverageVVals |            78.3 |
# |          StdVVals |         0.00375 |
# |          MaxVVals |            78.3 |
# |          MinVVals |            78.2 |
# | TotalEnvInteracts |        1.36e+05 |
# |            LossPi |          0.0639 |
# |             LossV |             594 |
# |       DeltaLossPi |         -0.0541 |
# |        DeltaLossV |           -3.32 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             252 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            79.7 |
# |          StdVVals |         0.00199 |
# |          MaxVVals |            79.7 |
# |          MinVVals |            79.7 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |          0.0521 |
# |             LossV |             598 |
# |       DeltaLossPi |          0.0118 |
# |        DeltaLossV |          -0.329 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             259 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             444 |
# |          StdEpRet |             113 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             158 |
# |             EpLen |             444 |
# |      AverageVVals |            80.2 |
# |          StdVVals |         0.00227 |
# |          MaxVVals |            80.2 |
# |          MinVVals |            80.2 |
# | TotalEnvInteracts |        1.44e+05 |
# |            LossPi |           0.116 |
# |             LossV |             590 |
# |       DeltaLossPi |         -0.0637 |
# |        DeltaLossV |         -0.0702 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |              80 |
# |          StdVVals |         0.00424 |
# |          MaxVVals |            80.1 |
# |          MinVVals |              80 |
# | TotalEnvInteracts |        1.48e+05 |
# |            LossPi |          0.0492 |
# |             LossV |             598 |
# |       DeltaLossPi |          0.0666 |
# |        DeltaLossV |         -0.0413 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             274 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             444 |
# |          StdEpRet |             114 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             134 |
# |             EpLen |             444 |
# |      AverageVVals |            80.3 |
# |          StdVVals |         0.00288 |
# |          MaxVVals |            80.3 |
# |          MinVVals |            80.3 |
# | TotalEnvInteracts |        1.52e+05 |
# |            LossPi |         0.00912 |
# |             LossV |             590 |
# |       DeltaLossPi |            0.04 |
# |        DeltaLossV |          -0.116 |
# |                KL |         0.00558 |
# |    BacktrackIters |               0 |
# |              Time |             281 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             444 |
# |          StdEpRet |            86.9 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             255 |
# |             EpLen |             444 |
# |      AverageVVals |              80 |
# |          StdVVals |         0.00158 |
# |          MaxVVals |              80 |
# |          MinVVals |              80 |
# | TotalEnvInteracts |        1.56e+05 |
# |            LossPi |           0.105 |
# |             LossV |             588 |
# |       DeltaLossPi |         -0.0958 |
# |        DeltaLossV |            0.02 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             289 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             444 |
# |          StdEpRet |             144 |
# |          MaxEpRet |             500 |
# |          MinEpRet |              40 |
# |             EpLen |             444 |
# |      AverageVVals |              80 |
# |          StdVVals |         0.00106 |
# |          MaxVVals |              80 |
# |          MinVVals |              80 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |          0.0057 |
# |             LossV |             595 |
# |       DeltaLossPi |          0.0992 |
# |        DeltaLossV |         -0.0596 |
# |                KL |         0.00789 |
# |    BacktrackIters |               0 |
# |              Time |             296 |
# ---------------------------------------
# Model 40 saved successfully
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             286 |
# |          StdEpRet |            87.7 |
# |          MaxEpRet |             427 |
# |          MinEpRet |             175 |
# |             EpLen |             286 |
# |      AverageVVals |            80.2 |
# |          StdVVals |        0.000876 |
# |          MaxVVals |            80.2 |
# |          MinVVals |            80.1 |
# | TotalEnvInteracts |        1.64e+05 |
# |            LossPi |         0.00738 |
# |             LossV |             678 |
# |       DeltaLossPi |        -0.00167 |
# |        DeltaLossV |            -107 |
# |                KL |         0.00594 |
# |    BacktrackIters |               0 |
# |              Time |             304 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             267 |
# |          StdEpRet |             104 |
# |          MaxEpRet |             480 |
# |          MinEpRet |              78 |
# |             EpLen |             267 |
# |      AverageVVals |            71.3 |
# |          StdVVals |         0.00357 |
# |          MaxVVals |            71.3 |
# |          MinVVals |            71.2 |
# | TotalEnvInteracts |        1.68e+05 |
# |            LossPi |             0.1 |
# |             LossV |             685 |
# |       DeltaLossPi |         -0.0926 |
# |        DeltaLossV |           -10.8 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             311 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             250 |
# |          StdEpRet |            88.1 |
# |          MaxEpRet |             496 |
# |          MinEpRet |             114 |
# |             EpLen |             250 |
# |      AverageVVals |            68.4 |
# |          StdVVals |          0.0151 |
# |          MaxVVals |            68.4 |
# |          MinVVals |            68.2 |
# | TotalEnvInteracts |        1.72e+05 |
# |            LossPi |           0.156 |
# |             LossV |             671 |
# |       DeltaLossPi |         -0.0565 |
# |        DeltaLossV |           -6.09 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             318 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             333 |
# |          StdEpRet |             121 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             120 |
# |             EpLen |             333 |
# |      AverageVVals |            66.2 |
# |          StdVVals |          0.0768 |
# |          MaxVVals |            66.2 |
# |          MinVVals |              65 |
# | TotalEnvInteracts |        1.76e+05 |
# |            LossPi |         0.00964 |
# |             LossV |             666 |
# |       DeltaLossPi |           0.147 |
# |        DeltaLossV |           -55.9 |
# |                KL |         0.00786 |
# |    BacktrackIters |               0 |
# |              Time |             325 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             308 |
# |          StdEpRet |             121 |
# |          MaxEpRet |             500 |
# |          MinEpRet |              76 |
# |             EpLen |             308 |
# |      AverageVVals |            72.6 |
# |          StdVVals |         0.00382 |
# |          MaxVVals |            72.6 |
# |          MinVVals |            72.6 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |           0.106 |
# |             LossV |             673 |
# |       DeltaLossPi |         -0.0959 |
# |        DeltaLossV |          -0.862 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             333 |
# |          StdEpRet |             133 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             132 |
# |             EpLen |             333 |
# |      AverageVVals |            71.8 |
# |          StdVVals |         0.00172 |
# |          MaxVVals |            71.8 |
# |          MinVVals |            71.8 |
# | TotalEnvInteracts |        1.84e+05 |
# |            LossPi |         0.00859 |
# |             LossV |             675 |
# |       DeltaLossPi |          0.0969 |
# |        DeltaLossV |           -4.59 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             339 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |             364 |
# |          StdEpRet |             115 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             203 |
# |             EpLen |             364 |
# |      AverageVVals |            73.7 |
# |          StdVVals |         0.00101 |
# |          MaxVVals |            73.7 |
# |          MinVVals |            73.7 |
# | TotalEnvInteracts |        1.88e+05 |
# |            LossPi |           0.187 |
# |             LossV |             642 |
# |       DeltaLossPi |          -0.179 |
# |        DeltaLossV |           -3.56 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             346 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |             333 |
# |          StdEpRet |             127 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             164 |
# |             EpLen |             333 |
# |      AverageVVals |            75.4 |
# |          StdVVals |         0.00174 |
# |          MaxVVals |            75.4 |
# |          MinVVals |            75.4 |
# | TotalEnvInteracts |        1.92e+05 |
# |            LossPi |          0.0711 |
# |             LossV |             680 |
# |       DeltaLossPi |           0.116 |
# |        DeltaLossV |           -1.54 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             353 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             333 |
# |          StdEpRet |             150 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             145 |
# |             EpLen |             333 |
# |      AverageVVals |            74.3 |
# |          StdVVals |          0.0015 |
# |          MaxVVals |            74.3 |
# |          MinVVals |            74.3 |
# | TotalEnvInteracts |        1.96e+05 |
# |            LossPi |         0.00703 |
# |             LossV |             684 |
# |       DeltaLossPi |          0.0641 |
# |        DeltaLossV |         0.00134 |
# |                KL |          0.0068 |
# |    BacktrackIters |               0 |
# |              Time |             360 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |             333 |
# |          StdEpRet |             113 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             166 |
# |             EpLen |             333 |
# |      AverageVVals |            74.3 |
# |          StdVVals |         0.00168 |
# |          MaxVVals |            74.3 |
# |          MinVVals |            74.2 |
# | TotalEnvInteracts |           2e+05 |
# |            LossPi |           0.049 |
# |             LossV |             659 |
# |       DeltaLossPi |          -0.042 |
# |        DeltaLossV |          -0.465 |
# |                KL |               0 |
# |    BacktrackIters |              10 |
# |              Time |             367 |
# ---------------------------------------
# Backtracking line search failed 28 times in total
# Model 50 (final) saved successfully
