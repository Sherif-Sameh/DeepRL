# %%
from spinup import ppo_pytorch as ppo
import torch
import gym

# %%
### Setup the environment and algorithm parameters

env_fn = lambda : gym.make('LunarLander-v2')
ac_kwargs = dict(hidden_sizes=[64, 64], activation=torch.nn.ReLU)
logger_kwargs = dict(output_dir='/home/sherif/user/python/spinningup/data', exp_name='Lunar_PPO_1')

# %%
### Running a single expirement

ppo(env_fn=env_fn, ac_kwargs=ac_kwargs, steps_per_epoch=5000, 
    epochs=250, logger_kwargs=logger_kwargs)
# Out:
# Warning: Log dir /home/sherif/user/python/spinningup/data already exists! Storing info there anyway.
# Logging data to /home/sherif/user/python/spinningup/data/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7843e97db7b8>",
#     "epochs":	250,
#     "exp_name":	"Lunar_PPO_1",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7843b9e21f28>":	{
#             "epoch_dict":	{},
#             "exp_name":	"Lunar_PPO_1",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/home/sherif/user/python/spinningup/data",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/home/sherif/user/python/spinningup/data/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"Lunar_PPO_1",
#         "output_dir":	"/home/sherif/user/python/spinningup/data"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 4996, 	 v: 4801
# /home/sherif/miniconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Warning: trajectory cut off by epoch at 44 steps.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            -202 |
# |          StdEpRet |             116 |
# |          MaxEpRet |           -25.4 |
# |          MinEpRet |            -560 |
# |             EpLen |            91.8 |
# |      AverageVVals |           -0.15 |
# |          StdVVals |          0.0428 |
# |          MaxVVals |         -0.0589 |
# |          MinVVals |          -0.415 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |        5.51e-08 |
# |             LossV |        1.57e+04 |
# |       DeltaLossPi |         -0.0127 |
# |        DeltaLossV |          -3e+03 |
# |           Entropy |            1.38 |
# |                KL |          0.0131 |
# |          ClipFrac |           0.111 |
# |          StopIter |              79 |
# |              Time |            3.06 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 74 steps.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -164 |
# |          StdEpRet |            84.5 |
# |          MaxEpRet |           -53.8 |
# |          MinEpRet |            -485 |
# |             EpLen |            98.5 |
# |      AverageVVals |           -13.9 |
# |          StdVVals |            1.72 |
# |          MaxVVals |            -9.8 |
# |          MinVVals |           -26.6 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |       -2.79e-08 |
# |             LossV |        7.27e+03 |
# |       DeltaLossPi |         -0.0146 |
# |        DeltaLossV |       -5.38e+03 |
# |           Entropy |            1.38 |
# |                KL |          0.0134 |
# |          ClipFrac |           0.115 |
# |          StopIter |              79 |
# |              Time |             5.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 56 steps.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -136 |
# |          StdEpRet |            89.1 |
# |          MaxEpRet |             0.6 |
# |          MinEpRet |            -420 |
# |             EpLen |            98.9 |
# |      AverageVVals |           -76.7 |
# |          StdVVals |            11.7 |
# |          MaxVVals |           -35.8 |
# |          MinVVals |            -172 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |       -3.65e-09 |
# |             LossV |         2.2e+03 |
# |       DeltaLossPi |         -0.0157 |
# |        DeltaLossV |            -172 |
# |           Entropy |            1.37 |
# |                KL |         0.00939 |
# |          ClipFrac |           0.114 |
# |          StopIter |              79 |
# |              Time |            8.07 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 69 steps.
# Early stopping at step 57 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -147 |
# |          StdEpRet |            85.6 |
# |          MaxEpRet |           -61.1 |
# |          MinEpRet |            -423 |
# |             EpLen |             105 |
# |      AverageVVals |             -71 |
# |          StdVVals |            9.02 |
# |          MaxVVals |           -49.2 |
# |          MinVVals |            -178 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |        1.76e-08 |
# |             LossV |        2.53e+03 |
# |       DeltaLossPi |         -0.0168 |
# |        DeltaLossV |            -219 |
# |           Entropy |            1.35 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.142 |
# |          StopIter |              57 |
# |              Time |            10.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 36 steps.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |           -98.5 |
# |          StdEpRet |            52.4 |
# |          MaxEpRet |           -16.4 |
# |          MinEpRet |            -239 |
# |             EpLen |             121 |
# |      AverageVVals |           -76.5 |
# |          StdVVals |            10.3 |
# |          MaxVVals |           -52.3 |
# |          MinVVals |            -167 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |        5.55e-08 |
# |             LossV |        1.82e+03 |
# |       DeltaLossPi |         -0.0189 |
# |        DeltaLossV |            -768 |
# |           Entropy |            1.33 |
# |                KL |           0.012 |
# |          ClipFrac |           0.191 |
# |          StopIter |              79 |
# |              Time |            13.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 55 steps.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -65.4 |
# |          StdEpRet |            41.7 |
# |          MaxEpRet |            38.4 |
# |          MinEpRet |            -159 |
# |             EpLen |             130 |
# |      AverageVVals |             -50 |
# |          StdVVals |            8.34 |
# |          MaxVVals |             -32 |
# |          MinVVals |            -140 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |        5.56e-09 |
# |             LossV |        1.18e+03 |
# |       DeltaLossPi |         -0.0131 |
# |        DeltaLossV |            -341 |
# |           Entropy |            1.29 |
# |                KL |          0.0112 |
# |          ClipFrac |           0.146 |
# |          StopIter |              79 |
# |              Time |            16.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 51 steps.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -66.8 |
# |          StdEpRet |            43.4 |
# |          MaxEpRet |            25.9 |
# |          MinEpRet |            -192 |
# |             EpLen |             130 |
# |      AverageVVals |           -34.7 |
# |          StdVVals |            9.41 |
# |          MaxVVals |           -18.5 |
# |          MinVVals |            -158 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |        1.52e-09 |
# |             LossV |             787 |
# |       DeltaLossPi |         -0.0177 |
# |        DeltaLossV |           -57.8 |
# |           Entropy |            1.24 |
# |                KL |          0.0137 |
# |          ClipFrac |           0.156 |
# |          StopIter |              79 |
# |              Time |            19.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 58 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -34.1 |
# |          StdEpRet |            61.2 |
# |          MaxEpRet |            36.5 |
# |          MinEpRet |            -182 |
# |             EpLen |             275 |
# |      AverageVVals |           -40.6 |
# |          StdVVals |            24.3 |
# |          MaxVVals |           -17.2 |
# |          MinVVals |            -130 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |        1.53e-08 |
# |             LossV |        2.15e+03 |
# |       DeltaLossPi |         -0.0131 |
# |        DeltaLossV |            -969 |
# |           Entropy |            1.24 |
# |                KL |          0.0113 |
# |          ClipFrac |            0.14 |
# |          StopIter |              79 |
# |              Time |            23.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 148 steps.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -59.5 |
# |          StdEpRet |            73.6 |
# |          MaxEpRet |            24.9 |
# |          MinEpRet |            -284 |
# |             EpLen |             255 |
# |      AverageVVals |             -16 |
# |          StdVVals |             8.6 |
# |          MaxVVals |           -5.85 |
# |          MinVVals |            -104 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |           2e-09 |
# |             LossV |        1.44e+03 |
# |       DeltaLossPi |         -0.0145 |
# |        DeltaLossV |            -309 |
# |           Entropy |            1.18 |
# |                KL |         0.00732 |
# |          ClipFrac |           0.145 |
# |          StopIter |              79 |
# |              Time |            26.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 20 steps.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |           -7.69 |
# |          StdEpRet |            81.4 |
# |          MaxEpRet |             107 |
# |          MinEpRet |            -210 |
# |             EpLen |             415 |
# |      AverageVVals |           -34.2 |
# |          StdVVals |              22 |
# |          MaxVVals |           -6.55 |
# |          MinVVals |           -99.5 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |       -2.44e-09 |
# |             LossV |        1.72e+03 |
# |       DeltaLossPi |         -0.0132 |
# |        DeltaLossV |            -721 |
# |           Entropy |            1.19 |
# |                KL |          0.0079 |
# |          ClipFrac |          0.0974 |
# |          StopIter |              79 |
# |              Time |            31.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 304 steps.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -40.4 |
# |          StdEpRet |            60.2 |
# |          MaxEpRet |            53.9 |
# |          MinEpRet |            -115 |
# |             EpLen |             671 |
# |      AverageVVals |           -8.68 |
# |          StdVVals |            9.54 |
# |          MaxVVals |            2.31 |
# |          MinVVals |           -38.9 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |        1.55e-08 |
# |             LossV |             699 |
# |       DeltaLossPi |         -0.0128 |
# |        DeltaLossV |           -17.1 |
# |           Entropy |            1.17 |
# |                KL |         0.00818 |
# |          ClipFrac |           0.108 |
# |          StopIter |              79 |
# |              Time |            36.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 987 steps.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -73.7 |
# |          StdEpRet |             102 |
# |          MaxEpRet |            40.9 |
# |          MinEpRet |            -255 |
# |             EpLen |             669 |
# |      AverageVVals |           -3.68 |
# |          StdVVals |            5.51 |
# |          MaxVVals |            3.83 |
# |          MinVVals |           -34.6 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |       -6.63e-09 |
# |             LossV |             738 |
# |       DeltaLossPi |         -0.0212 |
# |        DeltaLossV |           -76.2 |
# |           Entropy |            1.15 |
# |                KL |          0.0123 |
# |          ClipFrac |           0.197 |
# |          StopIter |              79 |
# |              Time |              42 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 308 steps.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |          -0.952 |
# |          StdEpRet |            49.3 |
# |          MaxEpRet |            91.1 |
# |          MinEpRet |           -63.5 |
# |             EpLen |             670 |
# |      AverageVVals |           -12.6 |
# |          StdVVals |            9.66 |
# |          MaxVVals |           -1.07 |
# |          MinVVals |           -45.3 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |        3.28e-09 |
# |             LossV |             546 |
# |       DeltaLossPi |         -0.0175 |
# |        DeltaLossV |           -81.9 |
# |           Entropy |            1.13 |
# |                KL |         0.00606 |
# |          ClipFrac |          0.0916 |
# |          StopIter |              79 |
# |              Time |            46.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 358 steps.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -10.6 |
# |          StdEpRet |            61.4 |
# |          MaxEpRet |             104 |
# |          MinEpRet |           -82.8 |
# |             EpLen |             516 |
# |      AverageVVals |           -2.52 |
# |          StdVVals |            5.02 |
# |          MaxVVals |            4.86 |
# |          MinVVals |           -32.1 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |       -1.11e-08 |
# |             LossV |             809 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |             -42 |
# |           Entropy |            1.13 |
# |                KL |          0.0136 |
# |          ClipFrac |           0.133 |
# |          StopIter |              79 |
# |              Time |            50.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 31 steps.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -78.8 |
# |          StdEpRet |              81 |
# |          MaxEpRet |            42.9 |
# |          MinEpRet |            -229 |
# |             EpLen |             828 |
# |      AverageVVals |           -3.24 |
# |          StdVVals |            5.98 |
# |          MaxVVals |            4.78 |
# |          MinVVals |           -34.4 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |       -2.32e-09 |
# |             LossV |             628 |
# |       DeltaLossPi |         -0.0169 |
# |        DeltaLossV |            -154 |
# |           Entropy |            1.09 |
# |                KL |         0.00963 |
# |          ClipFrac |           0.112 |
# |          StopIter |              79 |
# |              Time |            56.8 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 104 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -44.6 |
# |          StdEpRet |            48.6 |
# |          MaxEpRet |            43.8 |
# |          MinEpRet |           -92.9 |
# |             EpLen |             979 |
# |      AverageVVals |           -7.66 |
# |          StdVVals |            5.68 |
# |          MaxVVals |           0.705 |
# |          MinVVals |           -46.9 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |       -1.43e-08 |
# |             LossV |             262 |
# |       DeltaLossPi |         -0.0142 |
# |        DeltaLossV |           -15.3 |
# |           Entropy |            1.08 |
# |                KL |         0.00988 |
# |          ClipFrac |           0.166 |
# |          StopIter |              79 |
# |              Time |            62.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 376 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |           -65.7 |
# |          StdEpRet |             110 |
# |          MaxEpRet |            37.7 |
# |          MinEpRet |            -258 |
# |             EpLen |             925 |
# |      AverageVVals |           -8.07 |
# |          StdVVals |            9.53 |
# |          MaxVVals |            4.51 |
# |          MinVVals |           -51.5 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |       -2.06e-08 |
# |             LossV |             707 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |            -122 |
# |           Entropy |            1.03 |
# |                KL |         0.00647 |
# |          ClipFrac |          0.0742 |
# |          StopIter |              79 |
# |              Time |            68.5 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 856 steps.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |           -40.2 |
# |          StdEpRet |            24.5 |
# |          MaxEpRet |            2.44 |
# |          MinEpRet |           -73.9 |
# |             EpLen |             829 |
# |      AverageVVals |           -7.62 |
# |          StdVVals |            6.75 |
# |          MaxVVals |            3.28 |
# |          MinVVals |           -48.9 |
# | TotalEnvInteracts |           9e+04 |
# |            LossPi |       -1.57e-08 |
# |             LossV |             285 |
# |       DeltaLossPi |         -0.0126 |
# |        DeltaLossV |           -35.8 |
# |           Entropy |            1.04 |
# |                KL |         0.00701 |
# |          ClipFrac |          0.0766 |
# |          StopIter |              79 |
# |              Time |              74 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |            8.28 |
# |          StdEpRet |            32.6 |
# |          MaxEpRet |            57.4 |
# |          MinEpRet |             -30 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.04 |
# |          StdVVals |            7.86 |
# |          MaxVVals |            6.24 |
# |          MinVVals |           -31.4 |
# | TotalEnvInteracts |         9.5e+04 |
# |            LossPi |       -1.09e-08 |
# |             LossV |             127 |
# |       DeltaLossPi |        -0.00882 |
# |        DeltaLossV |           -32.9 |
# |           Entropy |            1.06 |
# |                KL |          0.0087 |
# |          ClipFrac |          0.0796 |
# |          StopIter |              79 |
# |              Time |            80.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             -36 |
# |          StdEpRet |            30.6 |
# |          MaxEpRet |            21.7 |
# |          MinEpRet |           -64.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.04 |
# |          StdVVals |            5.54 |
# |          MaxVVals |             9.1 |
# |          MinVVals |           -19.2 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |        1.71e-08 |
# |             LossV |              87 |
# |       DeltaLossPi |         -0.0105 |
# |        DeltaLossV |           -9.33 |
# |           Entropy |            1.04 |
# |                KL |         0.00785 |
# |          ClipFrac |           0.141 |
# |          StopIter |              79 |
# |              Time |            87.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 211 steps.
# Early stopping at step 9 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |           -40.9 |
# |          StdEpRet |            29.4 |
# |          MaxEpRet |           -23.7 |
# |          MinEpRet |           -99.5 |
# |             EpLen |             958 |
# |      AverageVVals |           -6.78 |
# |          StdVVals |            7.62 |
# |          MaxVVals |            5.46 |
# |          MinVVals |           -46.1 |
# | TotalEnvInteracts |        1.05e+05 |
# |            LossPi |       -9.27e-10 |
# |             LossV |             191 |
# |       DeltaLossPi |        -0.00303 |
# |        DeltaLossV |           -24.4 |
# |           Entropy |            1.02 |
# |                KL |          0.0155 |
# |          ClipFrac |           0.166 |
# |          StopIter |               9 |
# |              Time |            92.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 4 steps.
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |           -99.6 |
# |          StdEpRet |            65.3 |
# |          MaxEpRet |           -35.7 |
# |          MinEpRet |            -225 |
# |             EpLen |             999 |
# |      AverageVVals |           -7.18 |
# |          StdVVals |            8.47 |
# |          MaxVVals |            7.28 |
# |          MinVVals |           -64.5 |
# | TotalEnvInteracts |         1.1e+05 |
# |            LossPi |        5.05e-09 |
# |             LossV |             175 |
# |       DeltaLossPi |         -0.0115 |
# |        DeltaLossV |           -53.2 |
# |           Entropy |            1.01 |
# |                KL |         0.00746 |
# |          ClipFrac |           0.105 |
# |          StopIter |              79 |
# |              Time |            99.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |           -72.4 |
# |          StdEpRet |              18 |
# |          MaxEpRet |           -46.9 |
# |          MinEpRet |           -94.1 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.69 |
# |          StdVVals |            3.68 |
# |          MaxVVals |            1.55 |
# |          MinVVals |           -15.2 |
# | TotalEnvInteracts |        1.15e+05 |
# |            LossPi |       -1.91e-08 |
# |             LossV |            65.7 |
# |       DeltaLossPi |        -0.00584 |
# |        DeltaLossV |           -14.1 |
# |           Entropy |            1.02 |
# |                KL |         0.00865 |
# |          ClipFrac |          0.0908 |
# |          StopIter |              79 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |           -83.2 |
# |          StdEpRet |            20.7 |
# |          MaxEpRet |             -57 |
# |          MinEpRet |            -116 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -12.1 |
# |          StdVVals |            6.62 |
# |          MaxVVals |           -1.58 |
# |          MinVVals |           -32.2 |
# | TotalEnvInteracts |         1.2e+05 |
# |            LossPi |       -2.48e-08 |
# |             LossV |            77.5 |
# |       DeltaLossPi |        -0.00701 |
# |        DeltaLossV |             -18 |
# |           Entropy |           0.984 |
# |                KL |          0.0065 |
# |          ClipFrac |           0.067 |
# |          StopIter |              79 |
# |              Time |             111 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |           -42.8 |
# |          StdEpRet |            48.5 |
# |          MaxEpRet |            18.5 |
# |          MinEpRet |            -123 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -12.6 |
# |          StdVVals |            3.19 |
# |          MaxVVals |           -4.47 |
# |          MinVVals |           -28.6 |
# | TotalEnvInteracts |        1.25e+05 |
# |            LossPi |        3.24e-09 |
# |             LossV |             128 |
# |       DeltaLossPi |        -0.00612 |
# |        DeltaLossV |           -42.2 |
# |           Entropy |           0.976 |
# |                KL |         0.00718 |
# |          ClipFrac |          0.0728 |
# |          StopIter |              79 |
# |              Time |             117 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             -36 |
# |          StdEpRet |            28.7 |
# |          MaxEpRet |           -4.69 |
# |          MinEpRet |           -72.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.56 |
# |          StdVVals |            3.65 |
# |          MaxVVals |            1.81 |
# |          MinVVals |           -17.2 |
# | TotalEnvInteracts |         1.3e+05 |
# |            LossPi |        1.05e-08 |
# |             LossV |              76 |
# |       DeltaLossPi |         -0.0074 |
# |        DeltaLossV |           -4.93 |
# |           Entropy |           0.954 |
# |                KL |         0.00802 |
# |          ClipFrac |          0.0662 |
# |          StopIter |              79 |
# |              Time |             123 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -52.3 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |           -13.2 |
# |          MinEpRet |           -71.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -6.82 |
# |          StdVVals |            4.18 |
# |          MaxVVals |            4.59 |
# |          MinVVals |           -16.2 |
# | TotalEnvInteracts |        1.35e+05 |
# |            LossPi |        5.63e-09 |
# |             LossV |            39.6 |
# |       DeltaLossPi |        -0.00538 |
# |        DeltaLossV |           -2.41 |
# |           Entropy |            0.95 |
# |                KL |          0.0043 |
# |          ClipFrac |          0.0512 |
# |          StopIter |              79 |
# |              Time |             129 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |           -34.4 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |          -0.691 |
# |          MinEpRet |           -70.8 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -9.68 |
# |          StdVVals |            5.41 |
# |          MaxVVals |            1.24 |
# |          MinVVals |           -24.1 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |        1.49e-08 |
# |             LossV |            78.7 |
# |       DeltaLossPi |        -0.00554 |
# |        DeltaLossV |           -13.2 |
# |           Entropy |           0.953 |
# |                KL |          0.0042 |
# |          ClipFrac |          0.0348 |
# |          StopIter |              79 |
# |              Time |             137 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |           -47.1 |
# |          StdEpRet |            19.5 |
# |          MaxEpRet |             -15 |
# |          MinEpRet |           -66.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.97 |
# |          StdVVals |            4.23 |
# |          MaxVVals |            5.94 |
# |          MinVVals |           -14.3 |
# | TotalEnvInteracts |        1.45e+05 |
# |            LossPi |       -7.21e-09 |
# |             LossV |            39.1 |
# |       DeltaLossPi |        -0.00566 |
# |        DeltaLossV |           -2.64 |
# |           Entropy |           0.962 |
# |                KL |         0.00471 |
# |          ClipFrac |          0.0438 |
# |          StopIter |              79 |
# |              Time |             144 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |           -34.8 |
# |          StdEpRet |            15.2 |
# |          MaxEpRet |           -12.9 |
# |          MinEpRet |           -50.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -6.3 |
# |          StdVVals |            4.01 |
# |          MaxVVals |            6.54 |
# |          MinVVals |           -15.7 |
# | TotalEnvInteracts |         1.5e+05 |
# |            LossPi |       -1.04e-08 |
# |             LossV |            50.1 |
# |       DeltaLossPi |        -0.00555 |
# |        DeltaLossV |              -2 |
# |           Entropy |           0.948 |
# |                KL |         0.00611 |
# |          ClipFrac |          0.0668 |
# |          StopIter |              79 |
# |              Time |             151 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |           -51.7 |
# |          StdEpRet |            20.5 |
# |          MaxEpRet |           -30.1 |
# |          MinEpRet |             -85 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.31 |
# |          StdVVals |            3.07 |
# |          MaxVVals |            4.82 |
# |          MinVVals |           -11.3 |
# | TotalEnvInteracts |        1.55e+05 |
# |            LossPi |        -4.3e-09 |
# |             LossV |            70.3 |
# |       DeltaLossPi |        -0.00567 |
# |        DeltaLossV |           -9.05 |
# |           Entropy |           0.938 |
# |                KL |         0.00406 |
# |          ClipFrac |          0.0316 |
# |          StopIter |              79 |
# |              Time |             158 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             -64 |
# |          StdEpRet |            17.7 |
# |          MaxEpRet |           -29.5 |
# |          MinEpRet |             -80 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.07 |
# |          StdVVals |            3.01 |
# |          MaxVVals |            2.57 |
# |          MinVVals |           -13.3 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |        9.42e-09 |
# |             LossV |            28.2 |
# |       DeltaLossPi |        -0.00499 |
# |        DeltaLossV |           -1.38 |
# |           Entropy |           0.923 |
# |                KL |         0.00437 |
# |          ClipFrac |          0.0428 |
# |          StopIter |              79 |
# |              Time |             165 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |           -60.3 |
# |          StdEpRet |            11.2 |
# |          MaxEpRet |           -46.9 |
# |          MinEpRet |           -79.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.75 |
# |          StdVVals |             3.1 |
# |          MaxVVals |             4.8 |
# |          MinVVals |           -14.6 |
# | TotalEnvInteracts |        1.65e+05 |
# |            LossPi |       -6.23e-09 |
# |             LossV |            34.4 |
# |       DeltaLossPi |        -0.00458 |
# |        DeltaLossV |           -1.57 |
# |           Entropy |           0.923 |
# |                KL |         0.00574 |
# |          ClipFrac |          0.0534 |
# |          StopIter |              79 |
# |              Time |             173 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |           -40.3 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |           -19.8 |
# |          MinEpRet |           -61.8 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -9.62 |
# |          StdVVals |             3.5 |
# |          MaxVVals |            4.37 |
# |          MinVVals |           -15.6 |
# | TotalEnvInteracts |         1.7e+05 |
# |            LossPi |        6.62e-09 |
# |             LossV |              54 |
# |       DeltaLossPi |        -0.00458 |
# |        DeltaLossV |            -7.7 |
# |           Entropy |           0.911 |
# |                KL |         0.00297 |
# |          ClipFrac |           0.033 |
# |          StopIter |              79 |
# |              Time |             179 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             -45 |
# |          StdEpRet |            12.1 |
# |          MaxEpRet |           -25.8 |
# |          MinEpRet |           -58.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.09 |
# |          StdVVals |            4.23 |
# |          MaxVVals |            6.35 |
# |          MinVVals |           -15.8 |
# | TotalEnvInteracts |        1.75e+05 |
# |            LossPi |        8.48e-09 |
# |             LossV |            49.9 |
# |       DeltaLossPi |        -0.00498 |
# |        DeltaLossV |           -5.72 |
# |           Entropy |           0.893 |
# |                KL |         0.00364 |
# |          ClipFrac |          0.0326 |
# |          StopIter |              79 |
# |              Time |             186 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |           -43.1 |
# |          StdEpRet |            16.4 |
# |          MaxEpRet |           -23.7 |
# |          MinEpRet |           -71.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -9.1 |
# |          StdVVals |            4.96 |
# |          MaxVVals |            14.1 |
# |          MinVVals |           -18.8 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |        6.82e-09 |
# |             LossV |            31.3 |
# |       DeltaLossPi |        -0.00461 |
# |        DeltaLossV |           -3.34 |
# |           Entropy |           0.891 |
# |                KL |         0.00525 |
# |          ClipFrac |          0.0406 |
# |          StopIter |              79 |
# |              Time |             192 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |           -73.2 |
# |          StdEpRet |            24.6 |
# |          MaxEpRet |           -35.8 |
# |          MinEpRet |            -106 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -6.69 |
# |          StdVVals |            4.67 |
# |          MaxVVals |            17.2 |
# |          MinVVals |           -15.6 |
# | TotalEnvInteracts |        1.85e+05 |
# |            LossPi |       -4.21e-09 |
# |             LossV |            44.9 |
# |       DeltaLossPi |        -0.00559 |
# |        DeltaLossV |             -14 |
# |           Entropy |           0.892 |
# |                KL |         0.00646 |
# |          ClipFrac |          0.0524 |
# |          StopIter |              79 |
# |              Time |             198 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |           -63.9 |
# |          StdEpRet |            16.8 |
# |          MaxEpRet |           -47.2 |
# |          MinEpRet |           -92.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -9.92 |
# |          StdVVals |            4.48 |
# |          MaxVVals |            12.3 |
# |          MinVVals |             -17 |
# | TotalEnvInteracts |         1.9e+05 |
# |            LossPi |       -9.32e-09 |
# |             LossV |            37.2 |
# |       DeltaLossPi |         -0.0052 |
# |        DeltaLossV |           -5.18 |
# |           Entropy |           0.882 |
# |                KL |         0.00397 |
# |          ClipFrac |          0.0324 |
# |          StopIter |              79 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |           -68.7 |
# |          StdEpRet |            15.3 |
# |          MaxEpRet |             -48 |
# |          MinEpRet |           -87.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -9.64 |
# |          StdVVals |            4.56 |
# |          MaxVVals |             9.9 |
# |          MinVVals |           -16.9 |
# | TotalEnvInteracts |        1.95e+05 |
# |            LossPi |        -1.3e-08 |
# |             LossV |            16.5 |
# |       DeltaLossPi |        -0.00529 |
# |        DeltaLossV |            -1.3 |
# |           Entropy |           0.864 |
# |                KL |         0.00466 |
# |          ClipFrac |           0.033 |
# |          StopIter |              79 |
# |              Time |             210 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |           -32.8 |
# |          StdEpRet |            25.6 |
# |          MaxEpRet |            2.92 |
# |          MinEpRet |           -65.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.76 |
# |          StdVVals |            4.85 |
# |          MaxVVals |            11.8 |
# |          MinVVals |           -17.7 |
# | TotalEnvInteracts |           2e+05 |
# |            LossPi |       -3.91e-09 |
# |             LossV |            48.6 |
# |       DeltaLossPi |        -0.00441 |
# |        DeltaLossV |           -12.1 |
# |           Entropy |           0.859 |
# |                KL |         0.00314 |
# |          ClipFrac |          0.0312 |
# |          StopIter |              79 |
# |              Time |             217 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |           -41.2 |
# |          StdEpRet |            14.1 |
# |          MaxEpRet |           -22.4 |
# |          MinEpRet |             -64 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.33 |
# |          StdVVals |            5.21 |
# |          MaxVVals |            16.4 |
# |          MinVVals |           -16.9 |
# | TotalEnvInteracts |        2.05e+05 |
# |            LossPi |       -1.43e-08 |
# |             LossV |            35.9 |
# |       DeltaLossPi |        -0.00357 |
# |        DeltaLossV |           -5.05 |
# |           Entropy |           0.862 |
# |                KL |         0.00144 |
# |          ClipFrac |          0.0268 |
# |          StopIter |              79 |
# |              Time |             223 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |           -42.9 |
# |          StdEpRet |            26.5 |
# |          MaxEpRet |           -4.06 |
# |          MinEpRet |           -82.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.02 |
# |          StdVVals |            5.33 |
# |          MaxVVals |            16.7 |
# |          MinVVals |           -16.4 |
# | TotalEnvInteracts |         2.1e+05 |
# |            LossPi |        7.52e-09 |
# |             LossV |            27.5 |
# |       DeltaLossPi |        -0.00532 |
# |        DeltaLossV |           -4.13 |
# |           Entropy |           0.852 |
# |                KL |         0.00574 |
# |          ClipFrac |          0.0614 |
# |          StopIter |              79 |
# |              Time |             228 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |           -21.7 |
# |          StdEpRet |            22.8 |
# |          MaxEpRet |           0.094 |
# |          MinEpRet |           -62.1 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.92 |
# |          StdVVals |            5.63 |
# |          MaxVVals |            17.5 |
# |          MinVVals |           -13.6 |
# | TotalEnvInteracts |        2.15e+05 |
# |            LossPi |        4.14e-09 |
# |             LossV |            36.6 |
# |       DeltaLossPi |        -0.00459 |
# |        DeltaLossV |             -11 |
# |           Entropy |           0.841 |
# |                KL |         0.00746 |
# |          ClipFrac |          0.0394 |
# |          StopIter |              79 |
# |              Time |             235 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |           -55.6 |
# |          StdEpRet |            8.35 |
# |          MaxEpRet |           -48.2 |
# |          MinEpRet |           -71.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -6.4 |
# |          StdVVals |            4.58 |
# |          MaxVVals |            16.4 |
# |          MinVVals |           -14.6 |
# | TotalEnvInteracts |         2.2e+05 |
# |            LossPi |        1.67e-10 |
# |             LossV |              22 |
# |       DeltaLossPi |        -0.00389 |
# |        DeltaLossV |           -8.82 |
# |           Entropy |           0.868 |
# |                KL |         0.00322 |
# |          ClipFrac |           0.022 |
# |          StopIter |              79 |
# |              Time |             242 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |           -37.7 |
# |          StdEpRet |            11.3 |
# |          MaxEpRet |           -26.1 |
# |          MinEpRet |           -52.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -8.06 |
# |          StdVVals |            5.35 |
# |          MaxVVals |            19.9 |
# |          MinVVals |           -15.4 |
# | TotalEnvInteracts |        2.25e+05 |
# |            LossPi |       -1.25e-10 |
# |             LossV |            23.8 |
# |       DeltaLossPi |        -0.00513 |
# |        DeltaLossV |            -9.1 |
# |           Entropy |           0.861 |
# |                KL |         0.00505 |
# |          ClipFrac |            0.04 |
# |          StopIter |              79 |
# |              Time |             247 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |           -49.3 |
# |          StdEpRet |            14.8 |
# |          MaxEpRet |           -32.7 |
# |          MinEpRet |           -76.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.31 |
# |          StdVVals |            4.09 |
# |          MaxVVals |            15.1 |
# |          MinVVals |           -15.3 |
# | TotalEnvInteracts |         2.3e+05 |
# |            LossPi |        5.32e-09 |
# |             LossV |            13.8 |
# |       DeltaLossPi |        -0.00435 |
# |        DeltaLossV |              -2 |
# |           Entropy |            0.84 |
# |                KL |         0.00461 |
# |          ClipFrac |          0.0358 |
# |          StopIter |              79 |
# |              Time |             254 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |           -43.9 |
# |          StdEpRet |            23.6 |
# |          MaxEpRet |            -3.6 |
# |          MinEpRet |           -73.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.24 |
# |          StdVVals |            4.29 |
# |          MaxVVals |            19.8 |
# |          MinVVals |           -15.4 |
# | TotalEnvInteracts |        2.35e+05 |
# |            LossPi |        -6.8e-09 |
# |             LossV |            14.1 |
# |       DeltaLossPi |        -0.00297 |
# |        DeltaLossV |           -2.47 |
# |           Entropy |           0.843 |
# |                KL |         0.00438 |
# |          ClipFrac |          0.0176 |
# |          StopIter |              79 |
# |              Time |             261 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |           -43.2 |
# |          StdEpRet |              23 |
# |          MaxEpRet |           -12.2 |
# |          MinEpRet |           -70.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.56 |
# |          StdVVals |            4.52 |
# |          MaxVVals |            23.3 |
# |          MinVVals |           -15.6 |
# | TotalEnvInteracts |         2.4e+05 |
# |            LossPi |       -7.45e-10 |
# |             LossV |            10.8 |
# |       DeltaLossPi |        -0.00595 |
# |        DeltaLossV |           -2.19 |
# |           Entropy |           0.831 |
# |                KL |         0.00518 |
# |          ClipFrac |          0.0472 |
# |          StopIter |              79 |
# |              Time |             267 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |           -48.6 |
# |          StdEpRet |              19 |
# |          MaxEpRet |           -18.2 |
# |          MinEpRet |           -75.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -6.43 |
# |          StdVVals |            3.94 |
# |          MaxVVals |              26 |
# |          MinVVals |           -12.4 |
# | TotalEnvInteracts |        2.45e+05 |
# |            LossPi |        1.57e-08 |
# |             LossV |            10.1 |
# |       DeltaLossPi |        -0.00501 |
# |        DeltaLossV |            -1.1 |
# |           Entropy |           0.857 |
# |                KL |         0.00535 |
# |          ClipFrac |          0.0338 |
# |          StopIter |              79 |
# |              Time |             273 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |           -15.7 |
# |          StdEpRet |            21.2 |
# |          MaxEpRet |            3.81 |
# |          MinEpRet |           -54.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.51 |
# |          StdVVals |            6.93 |
# |          MaxVVals |            36.2 |
# |          MinVVals |           -12.2 |
# | TotalEnvInteracts |         2.5e+05 |
# |            LossPi |       -3.86e-09 |
# |             LossV |            13.5 |
# |       DeltaLossPi |        -0.00544 |
# |        DeltaLossV |           -4.01 |
# |           Entropy |           0.852 |
# |                KL |         0.00398 |
# |          ClipFrac |          0.0316 |
# |          StopIter |              79 |
# |              Time |             279 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |           -12.2 |
# |          StdEpRet |            6.55 |
# |          MaxEpRet |           -7.57 |
# |          MinEpRet |           -24.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.59 |
# |          StdVVals |            9.17 |
# |          MaxVVals |            43.6 |
# |          MinVVals |           -13.9 |
# | TotalEnvInteracts |        2.55e+05 |
# |            LossPi |        2.03e-08 |
# |             LossV |            13.7 |
# |       DeltaLossPi |        -0.00564 |
# |        DeltaLossV |           -1.95 |
# |           Entropy |           0.848 |
# |                KL |          0.0035 |
# |          ClipFrac |          0.0324 |
# |          StopIter |              79 |
# |              Time |             286 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |           -19.6 |
# |          StdEpRet |            22.1 |
# |          MaxEpRet |            14.7 |
# |          MinEpRet |           -54.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.23 |
# ...
# |          StopIter |              79 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 454 steps.
# ---------------------------------------
# |             Epoch |             233 |
# |      AverageEpRet |             246 |
# |          StdEpRet |            26.3 |
# |          MaxEpRet |             293 |
# |          MinEpRet |             206 |
# |             EpLen |             413 |
# |      AverageVVals |            46.9 |
# |          StdVVals |            24.5 |
# |          MaxVVals |             108 |
# |          MinVVals |            7.44 |
# | TotalEnvInteracts |        1.17e+06 |
# |            LossPi |       -9.42e-10 |
# |             LossV |            14.4 |
# |       DeltaLossPi |        -0.00489 |
# |        DeltaLossV |           -3.12 |
# |           Entropy |           0.481 |
# |                KL |         0.00248 |
# |          ClipFrac |          0.0322 |
# |          StopIter |              79 |
# |              Time |        1.21e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 440 steps.
# ---------------------------------------
# |             Epoch |             234 |
# |      AverageEpRet |             236 |
# |          StdEpRet |            23.3 |
# |          MaxEpRet |             279 |
# |          MinEpRet |             208 |
# |             EpLen |             456 |
# |      AverageVVals |            44.4 |
# |          StdVVals |            25.6 |
# |          MaxVVals |             114 |
# |          MinVVals |            3.12 |
# | TotalEnvInteracts |        1.18e+06 |
# |            LossPi |       -2.54e-09 |
# |             LossV |              40 |
# |       DeltaLossPi |        -0.00544 |
# |        DeltaLossV |           -7.77 |
# |           Entropy |             0.5 |
# |                KL |         0.00193 |
# |          ClipFrac |          0.0352 |
# |          StopIter |              79 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 257 steps.
# ---------------------------------------
# |             Epoch |             235 |
# |      AverageEpRet |             211 |
# |          StdEpRet |            55.2 |
# |          MaxEpRet |             259 |
# |          MinEpRet |            64.9 |
# |             EpLen |             527 |
# |      AverageVVals |            36.9 |
# |          StdVVals |            23.9 |
# |          MaxVVals |             104 |
# |          MinVVals |           -10.3 |
# | TotalEnvInteracts |        1.18e+06 |
# |            LossPi |       -2.32e-08 |
# |             LossV |             226 |
# |       DeltaLossPi |        -0.00742 |
# |        DeltaLossV |            -127 |
# |           Entropy |           0.529 |
# |                KL |         0.00462 |
# |          ClipFrac |          0.0478 |
# |          StopIter |              79 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 332 steps.
# ---------------------------------------
# |             Epoch |             236 |
# |      AverageEpRet |             246 |
# |          StdEpRet |            13.3 |
# |          MaxEpRet |             266 |
# |          MinEpRet |             229 |
# |             EpLen |             467 |
# |      AverageVVals |            45.1 |
# |          StdVVals |            25.4 |
# |          MaxVVals |             117 |
# |          MinVVals |            8.29 |
# | TotalEnvInteracts |        1.18e+06 |
# |            LossPi |        5.81e-09 |
# |             LossV |            58.8 |
# |       DeltaLossPi |        -0.00589 |
# |        DeltaLossV |           -23.1 |
# |           Entropy |           0.503 |
# |                KL |         0.00407 |
# |          ClipFrac |          0.0432 |
# |          StopIter |              79 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 279 steps.
# ---------------------------------------
# |             Epoch |             237 |
# |      AverageEpRet |             238 |
# |          StdEpRet |            46.3 |
# |          MaxEpRet |             279 |
# |          MinEpRet |             114 |
# |             EpLen |             472 |
# |      AverageVVals |            39.6 |
# |          StdVVals |            22.1 |
# |          MaxVVals |             103 |
# |          MinVVals |           0.355 |
# | TotalEnvInteracts |        1.19e+06 |
# |            LossPi |       -5.47e-09 |
# |             LossV |             190 |
# |       DeltaLossPi |        -0.00668 |
# |        DeltaLossV |            -115 |
# |           Entropy |           0.473 |
# |                KL |          0.0128 |
# |          ClipFrac |          0.0876 |
# |          StopIter |              79 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 202 steps.
# ---------------------------------------
# |             Epoch |             238 |
# |      AverageEpRet |             226 |
# |          StdEpRet |            37.9 |
# |          MaxEpRet |             262 |
# |          MinEpRet |             134 |
# |             EpLen |             480 |
# |      AverageVVals |            50.9 |
# |          StdVVals |            25.2 |
# |          MaxVVals |             114 |
# |          MinVVals |            8.91 |
# | TotalEnvInteracts |         1.2e+06 |
# |            LossPi |       -8.69e-09 |
# |             LossV |             824 |
# |       DeltaLossPi |        -0.00352 |
# |        DeltaLossV |            -703 |
# |           Entropy |           0.496 |
# |                KL |        0.000166 |
# |          ClipFrac |          0.0348 |
# |          StopIter |              79 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 214 steps.
# ---------------------------------------
# |             Epoch |             239 |
# |      AverageEpRet |             246 |
# |          StdEpRet |            25.2 |
# |          MaxEpRet |             292 |
# |          MinEpRet |             200 |
# |             EpLen |             435 |
# |      AverageVVals |            43.3 |
# |          StdVVals |            22.7 |
# |          MaxVVals |             101 |
# |          MinVVals |             1.8 |
# | TotalEnvInteracts |         1.2e+06 |
# |            LossPi |         9.3e-10 |
# |             LossV |            77.7 |
# |       DeltaLossPi |        -0.00603 |
# |        DeltaLossV |           -36.4 |
# |           Entropy |            0.47 |
# |                KL |         0.00445 |
# |          ClipFrac |           0.052 |
# |          StopIter |              79 |
# |              Time |        1.23e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 360 steps.
# ---------------------------------------
# |             Epoch |             240 |
# |      AverageEpRet |             257 |
# |          StdEpRet |            13.2 |
# |          MaxEpRet |             272 |
# |          MinEpRet |             228 |
# |             EpLen |             422 |
# |      AverageVVals |            47.3 |
# |          StdVVals |            22.7 |
# |          MaxVVals |             101 |
# |          MinVVals |            9.25 |
# | TotalEnvInteracts |        1.20e+06 |
# |            LossPi |        4.71e-09 |
# |             LossV |            20.2 |
# |       DeltaLossPi |        -0.00726 |
# |        DeltaLossV |           -7.72 |
# |           Entropy |           0.487 |
# |                KL |         0.00829 |
# |          ClipFrac |          0.0812 |
# |          StopIter |              79 |
# |              Time |        1.24e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 223 steps.
# Early stopping at step 12 due to reaching max kl.
# ---------------------------------------
# |             Epoch |             241 |
# |      AverageEpRet |             224 |
# |          StdEpRet |            41.2 |
# |          MaxEpRet |             287 |
# |          MinEpRet |             125 |
# |             EpLen |             478 |
# |      AverageVVals |              51 |
# |          StdVVals |            23.9 |
# |          MaxVVals |             108 |
# |          MinVVals |            9.06 |
# | TotalEnvInteracts |        1.21e+06 |
# |            LossPi |       -7.74e-08 |
# |             LossV |             683 |
# |       DeltaLossPi |        -0.00834 |
# |        DeltaLossV |            -560 |
# |           Entropy |           0.455 |
# |                KL |          0.0175 |
# |          ClipFrac |           0.117 |
# |          StopIter |              12 |
# |              Time |        1.24e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 307 steps.
# ---------------------------------------
# |             Epoch |             242 |
# |      AverageEpRet |             236 |
# |          StdEpRet |            54.2 |
# |          MaxEpRet |             293 |
# |          MinEpRet |            92.3 |
# |             EpLen |             469 |
# |      AverageVVals |            42.1 |
# |          StdVVals |            24.6 |
# |          MaxVVals |             104 |
# |          MinVVals |            1.26 |
# | TotalEnvInteracts |        1.22e+06 |
# |            LossPi |        -3.8e-09 |
# |             LossV |             112 |
# |       DeltaLossPi |        -0.00471 |
# |        DeltaLossV |           -24.1 |
# |           Entropy |           0.503 |
# |                KL |         0.00745 |
# |          ClipFrac |          0.0926 |
# |          StopIter |              79 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 153 steps.
# ---------------------------------------
# |             Epoch |             243 |
# |      AverageEpRet |             221 |
# |          StdEpRet |            42.5 |
# |          MaxEpRet |             274 |
# |          MinEpRet |             108 |
# |             EpLen |             485 |
# |      AverageVVals |            36.9 |
# |          StdVVals |            23.9 |
# |          MaxVVals |              97 |
# |          MinVVals |           -5.55 |
# | TotalEnvInteracts |        1.22e+06 |
# |            LossPi |       -3.88e-09 |
# |             LossV |            67.3 |
# |       DeltaLossPi |         -0.0052 |
# |        DeltaLossV |           -13.9 |
# |           Entropy |           0.531 |
# |                KL |         0.00324 |
# |          ClipFrac |          0.0736 |
# |          StopIter |              79 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 398 steps.
# ---------------------------------------
# |             Epoch |             244 |
# |      AverageEpRet |             215 |
# |          StdEpRet |            45.3 |
# |          MaxEpRet |             269 |
# |          MinEpRet |             100 |
# |             EpLen |             511 |
# |      AverageVVals |            39.1 |
# |          StdVVals |            26.1 |
# |          MaxVVals |             107 |
# |          MinVVals |           -6.61 |
# | TotalEnvInteracts |        1.22e+06 |
# |            LossPi |        1.47e-08 |
# |             LossV |            83.2 |
# |       DeltaLossPi |        -0.00381 |
# |        DeltaLossV |           -8.43 |
# |           Entropy |            0.53 |
# |                KL |         0.00674 |
# |          ClipFrac |          0.0612 |
# |          StopIter |              79 |
# |              Time |        1.25e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 882 steps.
# ---------------------------------------
# |             Epoch |             245 |
# |      AverageEpRet |             252 |
# |          StdEpRet |            18.9 |
# |          MaxEpRet |             286 |
# |          MinEpRet |             220 |
# |             EpLen |             412 |
# |      AverageVVals |            42.7 |
# |          StdVVals |            21.3 |
# |          MaxVVals |             102 |
# |          MinVVals |           -4.06 |
# | TotalEnvInteracts |        1.23e+06 |
# |            LossPi |       -1.88e-08 |
# |             LossV |             161 |
# |       DeltaLossPi |        -0.00413 |
# |        DeltaLossV |           -68.8 |
# |           Entropy |           0.468 |
# |                KL |         0.00362 |
# |          ClipFrac |          0.0462 |
# |          StopIter |              79 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 433 steps.
# ---------------------------------------
# |             Epoch |             246 |
# |      AverageEpRet |             242 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |             294 |
# |          MinEpRet |             202 |
# |             EpLen |             415 |
# |      AverageVVals |            46.3 |
# |          StdVVals |            23.3 |
# |          MaxVVals |             109 |
# |          MinVVals |              10 |
# | TotalEnvInteracts |        1.24e+06 |
# |            LossPi |        8.94e-10 |
# |             LossV |             143 |
# |       DeltaLossPi |        -0.00499 |
# |        DeltaLossV |            -105 |
# |           Entropy |            0.48 |
# |                KL |         0.00984 |
# |          ClipFrac |          0.0596 |
# |          StopIter |              79 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 306 steps.
# ---------------------------------------
# |             Epoch |             247 |
# |      AverageEpRet |             245 |
# |          StdEpRet |            17.1 |
# |          MaxEpRet |             271 |
# |          MinEpRet |             216 |
# |             EpLen |             427 |
# |      AverageVVals |            46.6 |
# |          StdVVals |            23.5 |
# |          MaxVVals |             110 |
# |          MinVVals |             3.6 |
# | TotalEnvInteracts |        1.24e+06 |
# |            LossPi |       -6.97e-09 |
# |             LossV |            27.5 |
# |       DeltaLossPi |        -0.00635 |
# |        DeltaLossV |           -6.36 |
# |           Entropy |           0.497 |
# |                KL |         0.00295 |
# |          ClipFrac |          0.0418 |
# |          StopIter |              79 |
# |              Time |        1.26e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 92 steps.
# ---------------------------------------
# |             Epoch |             248 |
# |      AverageEpRet |             241 |
# |          StdEpRet |            19.3 |
# |          MaxEpRet |             271 |
# |          MinEpRet |             212 |
# |             EpLen |             409 |
# |      AverageVVals |            48.1 |
# |          StdVVals |            23.7 |
# |          MaxVVals |             109 |
# |          MinVVals |            7.89 |
# | TotalEnvInteracts |        1.24e+06 |
# |            LossPi |       -2.35e-09 |
# |             LossV |              18 |
# |       DeltaLossPi |        -0.00465 |
# |        DeltaLossV |           -3.24 |
# |           Entropy |           0.499 |
# |                KL |          0.0052 |
# |          ClipFrac |          0.0404 |
# |          StopIter |              79 |
# |              Time |        1.27e+03 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 276 steps.
# ---------------------------------------
# |             Epoch |             249 |
# |      AverageEpRet |             233 |
# |          StdEpRet |            25.5 |
# |          MaxEpRet |             276 |
# |          MinEpRet |             183 |
# |             EpLen |             429 |
# |      AverageVVals |            46.4 |
# |          StdVVals |            22.9 |
# |          MaxVVals |             111 |
# |          MinVVals |            3.77 |
# | TotalEnvInteracts |        1.25e+06 |
# |            LossPi |        6.26e-09 |
# |             LossV |            40.1 |
# |       DeltaLossPi |        -0.00619 |
# |        DeltaLossV |           -13.9 |
# |           Entropy |           0.495 |
# |                KL |         0.00596 |
# |          ClipFrac |          0.0428 |
# |          StopIter |              79 |
# |              Time |        1.27e+03 |
# ---------------------------------------

# %%
### Using ExperimentalGrid to train multiple configurations (for hyperparameters) of the same algorithm sequentially

from spinup.utils.run_utils import ExperimentGrid
import argparse
import sys

sys.argv = ['01_experiments', '--cpu', '4', '--num_runs', '3']

parser = argparse.ArgumentParser()
parser.add_argument('--cpu', type=int, default=4)
parser.add_argument('--num_runs', type=int, default=3)
args = parser.parse_args()

eg = ExperimentGrid(name='ppo-pyt-bench')
eg.add('env_name', 'CartPole-v0', '', True)
eg.add('seed', [10*i for i in range(args.num_runs)])
eg.add('epochs', 10)
eg.add('steps_per_epoch', 4000)
eg.add('ac_kwargs:hidden_sizes', [(32, ), (64, 64)], 'hid')
eg.add('ac_kwargs:activation', [torch.nn.Tanh, torch.nn.ReLU], '')
eg.run(ppo, num_cpu=args.cpu)
# Out:
# ================================================================================
# ExperimentGrid [ppo-pyt-bench] runs over parameters:
#
#  env_name                                 []
#
# 	CartPole-v0
#
#  seed                                     [see]
#
# 	0
# 	10
# 	20
#
#  epochs                                   [epo]
#
# 	10
#
#  steps_per_epoch                          [ste]
#
# 	4000
#
#  ac_kwargs:hidden_sizes                   [hid]
#
# 	(32,)
# 	(64, 64)
#
#  ac_kwargs:activation                     []
#
# 	Tanh
# 	ReLU
#
#  Variants, counting seeds:               12
#  Variants, not counting seeds:           4
#
# ================================================================================
#
# Preparing to run the following experiments...
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
# ppo-pyt-bench_cartpole-v0_hid32_tanh
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# ================================================================================
#
# Launch delayed to give you a few seconds to review your experiments.
#
# To customize or disable this behavior, change WAIT_BEFORE_LAUNCH in
# spinup/user_config.py.
#
# ================================================================================
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s20
#
#
# ================================================================================

# %%
### Simulating trained policies (Doesn't work inside Jupyter Notebooks)

from spinup.utils.test_policy import load_policy_and_env, run_policy
_, get_action = load_policy_and_env('/home/sherif/user/python/spinningup/data')
env = gym.make('LunarLander-v2')
run_policy(env, get_action)
