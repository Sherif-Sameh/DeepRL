# %%
from spinup import ppo_pytorch as ppo
import torch
import gym

# %%
### Setup the environment and algorithm parameters

env_fn = lambda : gym.make('LunarLander-v2')
ac_kwargs = dict(hidden_sizes=[64, 64], activation=torch.nn.ReLU)
logger_kwargs = dict(output_dir='/home/sherif/user/python/spinningup/data/ppo', exp_name='Lunar_PPO_1')

# %%
### Running a single expirement

ppo(env_fn=env_fn, ac_kwargs=ac_kwargs, steps_per_epoch=5000, 
    epochs=250, logger_kwargs=logger_kwargs)
# Out:
# Logging data to /home/sherif/user/python/spinningup/data/ppo/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "clip_ratio":	0.2,
#     "env_fn":	"<function <lambda> at 0x7a10bfdf0ea0>",
#     "epochs":	250,
#     "exp_name":	"Lunar_PPO_1",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7a10bfdefac8>":	{
#             "epoch_dict":	{},
#             "exp_name":	"Lunar_PPO_1",
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/home/sherif/user/python/spinningup/data/ppo",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/home/sherif/user/python/spinningup/data/ppo/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{
#         "exp_name":	"Lunar_PPO_1",
#         "output_dir":	"/home/sherif/user/python/spinningup/data/ppo"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "save_freq":	10,
#     "seed":	0,
#     "steps_per_epoch":	5000,
#     "target_kl":	0.01,
#     "train_pi_iters":	80,
#     "train_v_iters":	80,
#     "vf_lr":	0.001
# }
#
# Number of parameters: 	 pi: 4996, 	 v: 4801
# /home/sherif/miniconda3/envs/spinningup/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Warning: trajectory cut off by epoch at 89 steps.
# ---------------------------------------
# |             Epoch |               0 |
# |      AverageEpRet |            -193 |
# |          StdEpRet |            95.1 |
# |          MaxEpRet |           -8.13 |
# |          MinEpRet |            -406 |
# |             EpLen |            96.3 |
# |      AverageVVals |          -0.153 |
# |          StdVVals |          0.0489 |
# |          MaxVVals |         -0.0691 |
# |          MinVVals |          -0.398 |
# | TotalEnvInteracts |           5e+03 |
# |            LossPi |       -2.24e-08 |
# |             LossV |        1.31e+04 |
# |       DeltaLossPi |         -0.0113 |
# |        DeltaLossV |        -2.7e+03 |
# |           Entropy |            1.38 |
# |                KL |         0.00502 |
# |          ClipFrac |           0.067 |
# |          StopIter |              79 |
# |              Time |            2.36 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 58 steps.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            -136 |
# |          StdEpRet |            57.9 |
# |          MaxEpRet |           -66.1 |
# |          MinEpRet |            -302 |
# |             EpLen |              95 |
# |      AverageVVals |           -13.9 |
# |          StdVVals |            3.05 |
# |          MaxVVals |            -7.4 |
# |          MinVVals |           -43.6 |
# | TotalEnvInteracts |           1e+04 |
# |            LossPi |        1.11e-07 |
# |             LossV |        4.74e+03 |
# |       DeltaLossPi |         -0.0139 |
# |        DeltaLossV |       -3.65e+03 |
# |           Entropy |            1.38 |
# |                KL |         0.00588 |
# |          ClipFrac |          0.0738 |
# |          StopIter |              79 |
# |              Time |            4.67 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 78 steps.
# Early stopping at step 39 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            -128 |
# |          StdEpRet |            61.3 |
# |          MaxEpRet |             -27 |
# |          MinEpRet |            -329 |
# |             EpLen |            91.1 |
# |      AverageVVals |           -67.8 |
# |          StdVVals |            11.5 |
# |          MaxVVals |           -32.1 |
# |          MinVVals |            -132 |
# | TotalEnvInteracts |         1.5e+04 |
# |            LossPi |        4.58e-09 |
# |             LossV |        1.65e+03 |
# |       DeltaLossPi |         -0.0139 |
# |        DeltaLossV |            -297 |
# |           Entropy |            1.37 |
# |                KL |           0.015 |
# |          ClipFrac |           0.139 |
# |          StopIter |              39 |
# |              Time |            6.79 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 6 steps.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            -135 |
# |          StdEpRet |            64.3 |
# |          MaxEpRet |           -44.3 |
# |          MinEpRet |            -324 |
# |             EpLen |            97.9 |
# |      AverageVVals |           -69.1 |
# |          StdVVals |            9.07 |
# |          MaxVVals |           -29.8 |
# |          MinVVals |            -162 |
# | TotalEnvInteracts |           2e+04 |
# |            LossPi |       -1.83e-09 |
# |             LossV |        1.82e+03 |
# |       DeltaLossPi |         -0.0205 |
# |        DeltaLossV |            -310 |
# |           Entropy |            1.36 |
# |                KL |          0.0126 |
# |          ClipFrac |           0.148 |
# |          StopIter |              79 |
# |              Time |            9.25 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 99 steps.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            -109 |
# |          StdEpRet |            63.5 |
# |          MaxEpRet |           -8.96 |
# |          MinEpRet |            -336 |
# |             EpLen |             104 |
# |      AverageVVals |           -72.9 |
# |          StdVVals |            9.89 |
# |          MaxVVals |           -45.8 |
# |          MinVVals |            -192 |
# | TotalEnvInteracts |         2.5e+04 |
# |            LossPi |       -6.91e-09 |
# |             LossV |        1.49e+03 |
# |       DeltaLossPi |         -0.0202 |
# |        DeltaLossV |            -270 |
# |           Entropy |            1.35 |
# |                KL |          0.0123 |
# |          ClipFrac |           0.169 |
# |          StopIter |              79 |
# |              Time |            11.6 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 20 steps.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |           -72.9 |
# |          StdEpRet |            51.4 |
# |          MaxEpRet |            31.8 |
# |          MinEpRet |            -262 |
# |             EpLen |             124 |
# |      AverageVVals |           -57.3 |
# |          StdVVals |            11.5 |
# |          MaxVVals |           -30.8 |
# |          MinVVals |            -223 |
# | TotalEnvInteracts |           3e+04 |
# |            LossPi |        2.37e-08 |
# |             LossV |        1.38e+03 |
# |       DeltaLossPi |         -0.0149 |
# |        DeltaLossV |            -475 |
# |           Entropy |            1.32 |
# |                KL |         0.00874 |
# |          ClipFrac |           0.129 |
# |          StopIter |              79 |
# |              Time |            13.9 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 76 steps.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |           -52.5 |
# |          StdEpRet |            47.4 |
# |          MaxEpRet |            46.4 |
# |          MinEpRet |            -171 |
# |             EpLen |             137 |
# |      AverageVVals |           -37.6 |
# |          StdVVals |            9.99 |
# |          MaxVVals |           -17.1 |
# |          MinVVals |            -107 |
# | TotalEnvInteracts |         3.5e+04 |
# |            LossPi |        2.24e-08 |
# |             LossV |        1.14e+03 |
# |       DeltaLossPi |         -0.0206 |
# |        DeltaLossV |            -185 |
# |           Entropy |            1.27 |
# |                KL |          0.0133 |
# |          ClipFrac |           0.213 |
# |          StopIter |              79 |
# |              Time |            16.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 43 steps.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |           -42.3 |
# |          StdEpRet |            49.5 |
# |          MaxEpRet |            59.4 |
# |          MinEpRet |            -166 |
# |             EpLen |             191 |
# |      AverageVVals |           -34.3 |
# |          StdVVals |            22.8 |
# |          MaxVVals |            -9.9 |
# |          MinVVals |            -123 |
# | TotalEnvInteracts |           4e+04 |
# |            LossPi |       -9.16e-09 |
# |             LossV |        2.02e+03 |
# |       DeltaLossPi |         -0.0142 |
# |        DeltaLossV |            -752 |
# |           Entropy |            1.22 |
# |                KL |          0.0138 |
# |          ClipFrac |           0.157 |
# |          StopIter |              79 |
# |              Time |              19 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 457 steps.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |           -67.1 |
# |          StdEpRet |            54.4 |
# |          MaxEpRet |             8.9 |
# |          MinEpRet |            -174 |
# |             EpLen |             379 |
# |      AverageVVals |           -20.4 |
# |          StdVVals |            9.59 |
# |          MaxVVals |           -7.11 |
# |          MinVVals |           -69.1 |
# | TotalEnvInteracts |         4.5e+04 |
# |            LossPi |        1.46e-09 |
# |             LossV |        1.07e+03 |
# |       DeltaLossPi |         -0.0152 |
# |        DeltaLossV |            -189 |
# |           Entropy |            1.22 |
# |                KL |         0.00599 |
# |          ClipFrac |          0.0942 |
# |          StopIter |              79 |
# |              Time |            23.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 894 steps.
# Early stopping at step 77 due to reaching max kl.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |           -91.2 |
# |          StdEpRet |            66.3 |
# |          MaxEpRet |          -0.139 |
# |          MinEpRet |            -225 |
# |             EpLen |             293 |
# |      AverageVVals |           -21.8 |
# |          StdVVals |            14.1 |
# |          MaxVVals |            -4.3 |
# |          MinVVals |           -78.1 |
# | TotalEnvInteracts |           5e+04 |
# |            LossPi |       -1.27e-08 |
# |             LossV |        1.49e+03 |
# |       DeltaLossPi |         -0.0184 |
# |        DeltaLossV |            -210 |
# |           Entropy |            1.19 |
# |                KL |          0.0151 |
# |          ClipFrac |           0.151 |
# |          StopIter |              77 |
# |              Time |            27.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 870 steps.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |           -55.1 |
# |          StdEpRet |            89.4 |
# |          MaxEpRet |            63.8 |
# |          MinEpRet |            -268 |
# |             EpLen |             413 |
# |      AverageVVals |           -24.4 |
# |          StdVVals |            22.4 |
# |          MaxVVals |           -1.85 |
# |          MinVVals |           -87.4 |
# | TotalEnvInteracts |         5.5e+04 |
# |            LossPi |       -9.71e-09 |
# |             LossV |        1.92e+03 |
# |       DeltaLossPi |         -0.0155 |
# |        DeltaLossV |            -611 |
# |           Entropy |            1.18 |
# |                KL |          0.0145 |
# |          ClipFrac |           0.142 |
# |          StopIter |              79 |
# |              Time |            31.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 42 steps.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |           -18.4 |
# |          StdEpRet |             102 |
# |          MaxEpRet |            69.2 |
# |          MinEpRet |            -276 |
# |             EpLen |             620 |
# |      AverageVVals |           -8.13 |
# |          StdVVals |            4.65 |
# |          MaxVVals |            1.26 |
# |          MinVVals |           -46.8 |
# | TotalEnvInteracts |           6e+04 |
# |            LossPi |        5.71e-09 |
# |             LossV |        1.16e+03 |
# |       DeltaLossPi |         -0.0166 |
# |        DeltaLossV |            -151 |
# |           Entropy |             1.2 |
# |                KL |          0.0127 |
# |          ClipFrac |           0.182 |
# |          StopIter |              79 |
# |              Time |            35.1 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 792 steps.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |           -68.8 |
# |          StdEpRet |            82.6 |
# |          MaxEpRet |            66.3 |
# |          MinEpRet |            -213 |
# |             EpLen |             601 |
# |      AverageVVals |           -5.71 |
# |          StdVVals |            10.1 |
# |          MaxVVals |            9.34 |
# |          MinVVals |           -47.8 |
# | TotalEnvInteracts |         6.5e+04 |
# |            LossPi |       -1.22e-08 |
# |             LossV |             958 |
# |       DeltaLossPi |         -0.0152 |
# |        DeltaLossV |            -180 |
# |           Entropy |            1.12 |
# |                KL |         0.00557 |
# |          ClipFrac |          0.0828 |
# |          StopIter |              79 |
# |              Time |            40.2 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 742 steps.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |           -25.4 |
# |          StdEpRet |            77.7 |
# |          MaxEpRet |            66.4 |
# |          MinEpRet |            -139 |
# |             EpLen |             710 |
# |      AverageVVals |           -14.7 |
# |          StdVVals |            9.59 |
# |          MaxVVals |           0.897 |
# |          MinVVals |           -54.1 |
# | TotalEnvInteracts |           7e+04 |
# |            LossPi |       -5.55e-09 |
# |             LossV |             761 |
# |       DeltaLossPi |         -0.0156 |
# |        DeltaLossV |            -248 |
# |           Entropy |            1.12 |
# |                KL |          0.0109 |
# |          ClipFrac |          0.0954 |
# |          StopIter |              79 |
# |              Time |            45.3 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 195 steps.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |           -69.4 |
# |          StdEpRet |            78.3 |
# |          MaxEpRet |            18.2 |
# |          MinEpRet |            -228 |
# |             EpLen |             801 |
# |      AverageVVals |           -1.78 |
# |          StdVVals |            8.77 |
# |          MaxVVals |            12.6 |
# |          MinVVals |           -50.9 |
# | TotalEnvInteracts |         7.5e+04 |
# |            LossPi |        9.65e-09 |
# |             LossV |             526 |
# |       DeltaLossPi |         -0.0115 |
# |        DeltaLossV |            -165 |
# |           Entropy |            1.09 |
# |                KL |         0.00833 |
# |          ClipFrac |          0.0688 |
# |          StopIter |              79 |
# |              Time |            50.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 720 steps.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |           -13.1 |
# |          StdEpRet |            41.2 |
# |          MaxEpRet |            48.1 |
# |          MinEpRet |           -69.1 |
# |             EpLen |             856 |
# |      AverageVVals |           -10.2 |
# |          StdVVals |            10.3 |
# |          MaxVVals |            11.1 |
# |          MinVVals |           -58.9 |
# | TotalEnvInteracts |           8e+04 |
# |            LossPi |        1.04e-08 |
# |             LossV |             361 |
# |       DeltaLossPi |         -0.0141 |
# |        DeltaLossV |           -72.6 |
# |           Entropy |            1.09 |
# |                KL |         0.00678 |
# |          ClipFrac |           0.106 |
# |          StopIter |              79 |
# |              Time |            55.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 197 steps.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |            18.2 |
# |          StdEpRet |            56.6 |
# |          MaxEpRet |             101 |
# |          MinEpRet |           -61.2 |
# |             EpLen |             961 |
# |      AverageVVals |           -2.55 |
# |          StdVVals |            8.84 |
# |          MaxVVals |            14.2 |
# |          MinVVals |           -35.2 |
# | TotalEnvInteracts |         8.5e+04 |
# |            LossPi |        7.98e-10 |
# |             LossV |             266 |
# |       DeltaLossPi |         -0.0115 |
# |        DeltaLossV |           -29.6 |
# |           Entropy |            1.07 |
# |                KL |         0.00791 |
# |          ClipFrac |          0.0696 |
# |          StopIter |              79 |
# |              Time |            62.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |            23.7 |
# |          StdEpRet |            47.7 |
# |          MaxEpRet |            69.1 |
# |          MinEpRet |           -54.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -1.67 |
# |          StdVVals |            6.38 |
# |          MaxVVals |            13.4 |
# |          MinVVals |             -33 |
# | TotalEnvInteracts |           9e+04 |
# |            LossPi |        1.24e-08 |
# |             LossV |             167 |
# |       DeltaLossPi |         -0.0124 |
# |        DeltaLossV |           -26.2 |
# |           Entropy |            1.07 |
# |                KL |         0.00719 |
# |          ClipFrac |          0.0612 |
# |          StopIter |              79 |
# |              Time |            68.4 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |              19 |
# |          StdEpRet |            34.1 |
# |          MaxEpRet |            49.3 |
# |          MinEpRet |           -44.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.786 |
# |          StdVVals |            6.04 |
# |          MaxVVals |            13.2 |
# |          MinVVals |           -35.5 |
# | TotalEnvInteracts |         9.5e+04 |
# |            LossPi |         1.5e-09 |
# |             LossV |             209 |
# |       DeltaLossPi |         -0.0105 |
# |        DeltaLossV |           -35.1 |
# |           Entropy |            1.04 |
# |                KL |         0.00704 |
# |          ClipFrac |          0.0842 |
# |          StopIter |              79 |
# |              Time |            74.4 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 245 steps.
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |            -4.8 |
# |          StdEpRet |            71.9 |
# |          MaxEpRet |            73.9 |
# |          MinEpRet |            -126 |
# |             EpLen |             951 |
# |      AverageVVals |            -2.5 |
# |          StdVVals |            5.86 |
# |          MaxVVals |            12.3 |
# |          MinVVals |           -26.5 |
# | TotalEnvInteracts |           1e+05 |
# |            LossPi |       -5.23e-09 |
# |             LossV |             315 |
# |       DeltaLossPi |         -0.0128 |
# |        DeltaLossV |           -31.8 |
# |           Entropy |            1.03 |
# |                KL |         0.00802 |
# |          ClipFrac |          0.0682 |
# |          StopIter |              79 |
# |              Time |            79.7 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 344 steps.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |            58.5 |
# |          StdEpRet |            67.2 |
# |          MaxEpRet |             124 |
# |          MinEpRet |           -71.1 |
# |             EpLen |             931 |
# |      AverageVVals |            2.45 |
# |          StdVVals |             4.1 |
# |          MaxVVals |            12.1 |
# |          MinVVals |           -15.2 |
# | TotalEnvInteracts |        1.05e+05 |
# |            LossPi |        6.14e-09 |
# |             LossV |             304 |
# |       DeltaLossPi |         -0.0093 |
# |        DeltaLossV |           -35.4 |
# |           Entropy |            1.04 |
# |                KL |         0.00619 |
# |          ClipFrac |          0.0542 |
# |          StopIter |              79 |
# |              Time |            85.3 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |            12.6 |
# |          StdEpRet |              40 |
# |          MaxEpRet |            63.3 |
# |          MinEpRet |           -56.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -0.25 |
# |          StdVVals |            7.61 |
# |          MaxVVals |            20.6 |
# |          MinVVals |           -28.8 |
# | TotalEnvInteracts |         1.1e+05 |
# |            LossPi |         1.1e-10 |
# |             LossV |             107 |
# |       DeltaLossPi |        -0.00834 |
# |        DeltaLossV |           -19.2 |
# |           Entropy |            1.02 |
# |                KL |         0.00728 |
# |          ClipFrac |          0.0628 |
# |          StopIter |              79 |
# |              Time |            91.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |            38.1 |
# |          StdEpRet |            36.3 |
# |          MaxEpRet |            99.5 |
# |          MinEpRet |            -2.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            1.98 |
# |          StdVVals |            6.13 |
# |          MaxVVals |            20.7 |
# |          MinVVals |           -20.2 |
# | TotalEnvInteracts |        1.15e+05 |
# |            LossPi |       -1.07e-08 |
# |             LossV |            97.3 |
# |       DeltaLossPi |        -0.00956 |
# |        DeltaLossV |           -12.9 |
# |           Entropy |           0.993 |
# |                KL |         0.00403 |
# |          ClipFrac |          0.0416 |
# |          StopIter |              79 |
# |              Time |            97.1 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |            16.2 |
# |          StdEpRet |            50.8 |
# |          MaxEpRet |            69.2 |
# |          MinEpRet |           -49.8 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.856 |
# |          StdVVals |            5.21 |
# |          MaxVVals |            18.4 |
# |          MinVVals |             -14 |
# | TotalEnvInteracts |         1.2e+05 |
# |            LossPi |       -9.12e-09 |
# |             LossV |            66.6 |
# |       DeltaLossPi |         -0.0112 |
# |        DeltaLossV |           -13.1 |
# |           Entropy |           0.987 |
# |                KL |         0.00492 |
# |          ClipFrac |          0.0926 |
# |          StopIter |              79 |
# |              Time |             103 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |          -0.518 |
# |          StdEpRet |            37.9 |
# |          MaxEpRet |            48.7 |
# |          MinEpRet |           -51.1 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.47 |
# |          StdVVals |            4.02 |
# |          MaxVVals |              14 |
# |          MinVVals |             -16 |
# | TotalEnvInteracts |        1.25e+05 |
# |            LossPi |        3.23e-09 |
# |             LossV |            86.1 |
# |       DeltaLossPi |        -0.00931 |
# |        DeltaLossV |           -13.9 |
# |           Entropy |           0.981 |
# |                KL |         0.00639 |
# |          ClipFrac |            0.07 |
# |          StopIter |              79 |
# |              Time |             110 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 340 steps.
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |            16.5 |
# |          StdEpRet |            61.4 |
# |          MaxEpRet |            78.8 |
# |          MinEpRet |            -101 |
# |             EpLen |             932 |
# |      AverageVVals |            1.48 |
# |          StdVVals |            4.21 |
# |          MaxVVals |            17.1 |
# |          MinVVals |           -12.3 |
# | TotalEnvInteracts |         1.3e+05 |
# |            LossPi |        5.61e-10 |
# |             LossV |             252 |
# |       DeltaLossPi |         -0.0109 |
# |        DeltaLossV |           -44.2 |
# |           Entropy |           0.949 |
# |                KL |         0.00606 |
# |          ClipFrac |          0.0568 |
# |          StopIter |              79 |
# |              Time |             115 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |           -7.66 |
# |          StdEpRet |              30 |
# |          MaxEpRet |            31.1 |
# |          MinEpRet |           -53.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -4.4 |
# |          StdVVals |            6.03 |
# |          MaxVVals |            13.5 |
# |          MinVVals |           -18.5 |
# | TotalEnvInteracts |        1.35e+05 |
# |            LossPi |        2.31e-09 |
# |             LossV |            81.8 |
# |       DeltaLossPi |        -0.00754 |
# |        DeltaLossV |           -16.5 |
# |           Entropy |           0.946 |
# |                KL |         0.00664 |
# |          ClipFrac |          0.0644 |
# |          StopIter |              79 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |            36.3 |
# |          StdEpRet |            35.5 |
# |          MaxEpRet |            62.4 |
# |          MinEpRet |           -33.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |          -0.853 |
# |          StdVVals |            6.71 |
# |          MaxVVals |            22.9 |
# |          MinVVals |             -15 |
# | TotalEnvInteracts |         1.4e+05 |
# |            LossPi |        1.31e-08 |
# |             LossV |            80.1 |
# |       DeltaLossPi |         -0.0084 |
# |        DeltaLossV |           -28.2 |
# |           Entropy |            0.96 |
# |                KL |          0.0125 |
# |          ClipFrac |           0.056 |
# |          StopIter |              79 |
# |              Time |             127 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 117 steps.
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |            28.5 |
# |          StdEpRet |            35.7 |
# |          MaxEpRet |            96.2 |
# |          MinEpRet |            -1.4 |
# |             EpLen |             977 |
# |      AverageVVals |          -0.791 |
# |          StdVVals |            8.94 |
# |          MaxVVals |            35.2 |
# |          MinVVals |           -22.1 |
# | TotalEnvInteracts |        1.45e+05 |
# |            LossPi |       -3.28e-09 |
# |             LossV |             209 |
# |       DeltaLossPi |         -0.0096 |
# |        DeltaLossV |           -83.7 |
# |           Entropy |            0.91 |
# |                KL |         0.00903 |
# |          ClipFrac |           0.112 |
# |          StopIter |              79 |
# |              Time |             133 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |              36 |
# |          StdEpRet |            37.1 |
# |          MaxEpRet |            64.8 |
# |          MinEpRet |           -30.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            2.27 |
# |          StdVVals |            6.87 |
# |          MaxVVals |            33.5 |
# |          MinVVals |           -16.4 |
# | TotalEnvInteracts |         1.5e+05 |
# |            LossPi |        6.16e-09 |
# |             LossV |             104 |
# |       DeltaLossPi |          -0.012 |
# |        DeltaLossV |           -42.8 |
# |           Entropy |           0.935 |
# |                KL |         0.00744 |
# |          ClipFrac |          0.0856 |
# |          StopIter |              79 |
# |              Time |             139 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 803 steps.
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |            58.9 |
# |          StdEpRet |            84.2 |
# |          MaxEpRet |             157 |
# |          MinEpRet |             -91 |
# |             EpLen |             839 |
# |      AverageVVals |           -0.28 |
# |          StdVVals |            5.74 |
# |          MaxVVals |              39 |
# |          MinVVals |           -16.4 |
# | TotalEnvInteracts |        1.55e+05 |
# |            LossPi |        6.27e-09 |
# |             LossV |             469 |
# |       DeltaLossPi |          -0.013 |
# |        DeltaLossV |            -151 |
# |           Entropy |           0.903 |
# |                KL |           0.014 |
# |          ClipFrac |          0.0896 |
# |          StopIter |              79 |
# |              Time |             144 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |            45.8 |
# |          StdEpRet |            16.1 |
# |          MaxEpRet |            59.9 |
# |          MinEpRet |            15.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            6.54 |
# |          StdVVals |            10.6 |
# |          MaxVVals |            46.6 |
# |          MinVVals |           -13.3 |
# | TotalEnvInteracts |         1.6e+05 |
# |            LossPi |        1.08e-08 |
# |             LossV |             114 |
# |       DeltaLossPi |        -0.00757 |
# |        DeltaLossV |           -74.3 |
# |           Entropy |           0.882 |
# |                KL |         0.00659 |
# |          ClipFrac |          0.0664 |
# |          StopIter |              79 |
# |              Time |             150 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 232 steps.
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |              23 |
# |          StdEpRet |              83 |
# |          MaxEpRet |             123 |
# |          MinEpRet |             -89 |
# |             EpLen |             795 |
# |      AverageVVals |            4.76 |
# |          StdVVals |            6.13 |
# |          MaxVVals |            35.7 |
# |          MinVVals |           -11.3 |
# | TotalEnvInteracts |        1.65e+05 |
# |            LossPi |       -7.42e-09 |
# |             LossV |             540 |
# |       DeltaLossPi |         -0.0124 |
# |        DeltaLossV |            -152 |
# |           Entropy |           0.877 |
# |                KL |          0.0118 |
# |          ClipFrac |          0.0892 |
# |          StopIter |              79 |
# |              Time |             155 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 1 steps.
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |            63.8 |
# |          StdEpRet |            72.8 |
# |          MaxEpRet |             140 |
# |          MinEpRet |           -79.4 |
# |             EpLen |             833 |
# |      AverageVVals |          -0.335 |
# |          StdVVals |            9.85 |
# |          MaxVVals |              48 |
# |          MinVVals |           -23.2 |
# | TotalEnvInteracts |         1.7e+05 |
# |            LossPi |       -7.08e-09 |
# |             LossV |             395 |
# |       DeltaLossPi |        -0.00689 |
# |        DeltaLossV |            -169 |
# |           Entropy |           0.957 |
# |                KL |         0.00577 |
# |          ClipFrac |          0.0226 |
# |          StopIter |              79 |
# |              Time |             161 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 212 steps.
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |            49.2 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |            99.4 |
# |          MinEpRet |            17.3 |
# |             EpLen |             958 |
# |      AverageVVals |            3.67 |
# |          StdVVals |            5.49 |
# |          MaxVVals |            33.2 |
# |          MinVVals |           -11.6 |
# | TotalEnvInteracts |        1.75e+05 |
# |            LossPi |        4.62e-10 |
# |             LossV |             114 |
# |       DeltaLossPi |        -0.00618 |
# |        DeltaLossV |           -51.4 |
# |           Entropy |           0.919 |
# |                KL |         0.00594 |
# |          ClipFrac |           0.034 |
# |          StopIter |              79 |
# |              Time |             167 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 639 steps.
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             104 |
# |          StdEpRet |            45.6 |
# |          MaxEpRet |             174 |
# |          MinEpRet |            59.4 |
# |             EpLen |             872 |
# |      AverageVVals |            7.32 |
# |          StdVVals |            8.76 |
# |          MaxVVals |            74.1 |
# |          MinVVals |           -4.78 |
# | TotalEnvInteracts |         1.8e+05 |
# |            LossPi |       -2.31e-09 |
# |             LossV |             141 |
# |       DeltaLossPi |        -0.00677 |
# |        DeltaLossV |           -23.1 |
# |           Entropy |           0.861 |
# |                KL |          0.0075 |
# |          ClipFrac |          0.0558 |
# |          StopIter |              79 |
# |              Time |             172 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 918 steps.
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |            33.1 |
# |          StdEpRet |            89.3 |
# |          MaxEpRet |             110 |
# |          MinEpRet |            -131 |
# |             EpLen |             816 |
# |      AverageVVals |            8.97 |
# |          StdVVals |            13.6 |
# |          MaxVVals |             126 |
# |          MinVVals |           -5.67 |
# | TotalEnvInteracts |        1.85e+05 |
# |            LossPi |        1.16e-08 |
# |             LossV |             444 |
# |       DeltaLossPi |        -0.00844 |
# |        DeltaLossV |            -188 |
# |           Entropy |           0.886 |
# |                KL |         0.00676 |
# |          ClipFrac |          0.0646 |
# |          StopIter |              79 |
# |              Time |             178 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 760 steps.
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |            46.7 |
# |          StdEpRet |              90 |
# |          MaxEpRet |             152 |
# |          MinEpRet |            -121 |
# |             EpLen |             848 |
# |      AverageVVals |          -0.094 |
# |          StdVVals |            9.78 |
# |          MaxVVals |              51 |
# |          MinVVals |           -22.2 |
# | TotalEnvInteracts |         1.9e+05 |
# |            LossPi |       -8.26e-09 |
# |             LossV |             200 |
# |       DeltaLossPi |        -0.00779 |
# |        DeltaLossV |           -88.2 |
# |           Entropy |           0.894 |
# |                KL |          0.0063 |
# |          ClipFrac |          0.0802 |
# |          StopIter |              79 |
# |              Time |             184 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 789 steps.
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |            66.3 |
# |          StdEpRet |            70.6 |
# |          MaxEpRet |             147 |
# |          MinEpRet |           -59.7 |
# |             EpLen |             842 |
# |      AverageVVals |            5.29 |
# |          StdVVals |            11.6 |
# |          MaxVVals |            61.2 |
# |          MinVVals |           -26.6 |
# | TotalEnvInteracts |        1.95e+05 |
# |            LossPi |        -9.8e-09 |
# |             LossV |             171 |
# |       DeltaLossPi |         -0.0079 |
# |        DeltaLossV |           -70.2 |
# |           Entropy |           0.885 |
# |                KL |          0.0063 |
# |          ClipFrac |          0.0734 |
# |          StopIter |              79 |
# |              Time |             190 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 487 steps.
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |            45.5 |
# |          StdEpRet |            49.5 |
# |          MaxEpRet |             116 |
# |          MinEpRet |           -38.5 |
# |             EpLen |             903 |
# |      AverageVVals |            1.68 |
# |          StdVVals |            11.9 |
# |          MaxVVals |            61.2 |
# |          MinVVals |           -35.5 |
# | TotalEnvInteracts |           2e+05 |
# |            LossPi |        -8.9e-09 |
# |             LossV |             187 |
# |       DeltaLossPi |        -0.00873 |
# |        DeltaLossV |           -45.1 |
# |           Entropy |            0.91 |
# |                KL |         0.00934 |
# |          ClipFrac |          0.0828 |
# |          StopIter |              79 |
# |              Time |             195 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |            83.5 |
# |          StdEpRet |            22.2 |
# |          MaxEpRet |             123 |
# |          MinEpRet |            59.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            3.89 |
# |          StdVVals |            8.92 |
# |          MaxVVals |            61.4 |
# |          MinVVals |           -18.4 |
# | TotalEnvInteracts |        2.05e+05 |
# |            LossPi |       -6.98e-09 |
# |             LossV |              62 |
# |       DeltaLossPi |        -0.00942 |
# |        DeltaLossV |           -40.7 |
# |           Entropy |           0.961 |
# |                KL |          0.0116 |
# |          ClipFrac |          0.0698 |
# |          StopIter |              79 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |              70 |
# |          StdEpRet |            24.8 |
# |          MaxEpRet |            91.9 |
# |          MinEpRet |            22.1 |
# |             EpLen |           1e+03 |
# |      AverageVVals |             4.5 |
# |          StdVVals |            7.41 |
# |          MaxVVals |            34.2 |
# |          MinVVals |           -8.63 |
# | TotalEnvInteracts |         2.1e+05 |
# |            LossPi |        3.48e-09 |
# |             LossV |            13.2 |
# |       DeltaLossPi |        -0.00885 |
# |        DeltaLossV |           -2.89 |
# |           Entropy |           0.953 |
# |                KL |         0.00285 |
# |          ClipFrac |          0.0724 |
# |          StopIter |              79 |
# |              Time |             207 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 446 steps.
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |            85.3 |
# |          StdEpRet |            28.2 |
# |          MaxEpRet |             137 |
# |          MinEpRet |              58 |
# |             EpLen |             911 |
# |      AverageVVals |            5.48 |
# |          StdVVals |            10.1 |
# |          MaxVVals |            61.1 |
# |          MinVVals |           -16.7 |
# | TotalEnvInteracts |        2.15e+05 |
# |            LossPi |        1.14e-09 |
# |             LossV |            53.6 |
# |       DeltaLossPi |        -0.00423 |
# |        DeltaLossV |           -26.1 |
# |           Entropy |            0.92 |
# |                KL |         0.00646 |
# |          ClipFrac |          0.0824 |
# |          StopIter |              79 |
# |              Time |             213 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 353 steps.
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |            53.4 |
# |          StdEpRet |            50.9 |
# |          MaxEpRet |            83.1 |
# |          MinEpRet |           -47.7 |
# |             EpLen |             929 |
# |      AverageVVals |            4.86 |
# |          StdVVals |            9.68 |
# |          MaxVVals |            58.8 |
# |          MinVVals |           -9.42 |
# | TotalEnvInteracts |         2.2e+05 |
# |            LossPi |        6.87e-09 |
# |             LossV |             178 |
# |       DeltaLossPi |         -0.0104 |
# |        DeltaLossV |           -89.4 |
# |           Entropy |           0.918 |
# |                KL |         0.00799 |
# |          ClipFrac |           0.039 |
# |          StopIter |              79 |
# |              Time |             218 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 971 steps.
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             125 |
# |          StdEpRet |            50.5 |
# |          MaxEpRet |             193 |
# |          MinEpRet |            49.9 |
# |             EpLen |             806 |
# |      AverageVVals |            4.21 |
# |          StdVVals |              10 |
# |          MaxVVals |            60.9 |
# |          MinVVals |           -18.6 |
# | TotalEnvInteracts |        2.25e+05 |
# |            LossPi |       -4.52e-09 |
# |             LossV |             325 |
# |       DeltaLossPi |        -0.00977 |
# |        DeltaLossV |            -177 |
# |           Entropy |           0.882 |
# |                KL |          0.0145 |
# |          ClipFrac |           0.115 |
# |          StopIter |              79 |
# |              Time |             223 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 641 steps.
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |            55.6 |
# |          StdEpRet |            74.8 |
# |          MaxEpRet |             163 |
# |          MinEpRet |           -71.2 |
# |             EpLen |             872 |
# |      AverageVVals |            8.95 |
# |          StdVVals |            7.41 |
# |          MaxVVals |            51.1 |
# |          MinVVals |           -3.11 |
# | TotalEnvInteracts |         2.3e+05 |
# |            LossPi |        1.04e-08 |
# |             LossV |             233 |
# |       DeltaLossPi |        -0.00782 |
# |        DeltaLossV |           -92.5 |
# |           Entropy |           0.916 |
# |                KL |         0.00633 |
# |          ClipFrac |          0.0716 |
# |          StopIter |              79 |
# |              Time |             228 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 374 steps.
# ---------------------------------------
# |             Epoch |              46 |
# |      AverageEpRet |            52.9 |
# |          StdEpRet |            46.5 |
# |          MaxEpRet |            87.6 |
# |          MinEpRet |           -35.6 |
# |             EpLen |             925 |
# |      AverageVVals |            3.93 |
# |          StdVVals |            11.7 |
# |          MaxVVals |            60.3 |
# |          MinVVals |           -20.2 |
# | TotalEnvInteracts |        2.35e+05 |
# |            LossPi |        -1.1e-08 |
# |             LossV |             159 |
# |       DeltaLossPi |         -0.0109 |
# |        DeltaLossV |           -44.9 |
# |           Entropy |           0.885 |
# |                KL |         0.00841 |
# |          ClipFrac |           0.059 |
# |          StopIter |              79 |
# |              Time |             234 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              47 |
# |      AverageEpRet |            97.2 |
# |          StdEpRet |            15.9 |
# |          MaxEpRet |             116 |
# |          MinEpRet |            72.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |             3.2 |
# |          StdVVals |            12.1 |
# |          MaxVVals |            84.6 |
# |          MinVVals |           -17.9 |
# | TotalEnvInteracts |         2.4e+05 |
# |            LossPi |        3.25e-09 |
# |             LossV |            65.8 |
# |       DeltaLossPi |         -0.0118 |
# |        DeltaLossV |           -50.8 |
# |           Entropy |           0.968 |
# |                KL |         0.00748 |
# |          ClipFrac |           0.059 |
# |          StopIter |              79 |
# |              Time |             240 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 677 steps.
# ---------------------------------------
# |             Epoch |              48 |
# |      AverageEpRet |             115 |
# |          StdEpRet |            44.7 |
# |          MaxEpRet |             174 |
# |          MinEpRet |              60 |
# |             EpLen |             865 |
# |      AverageVVals |            8.56 |
# |          StdVVals |            13.4 |
# |          MaxVVals |            93.3 |
# |          MinVVals |           -9.29 |
# | TotalEnvInteracts |        2.45e+05 |
# |            LossPi |        1.39e-08 |
# |             LossV |             196 |
# |       DeltaLossPi |        -0.00366 |
# |        DeltaLossV |            -117 |
# |           Entropy |           0.894 |
# |                KL |         0.00829 |
# |          ClipFrac |          0.0606 |
# |          StopIter |              79 |
# |              Time |             245 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 338 steps.
# ---------------------------------------
# |             Epoch |              49 |
# |      AverageEpRet |            98.9 |
# |          StdEpRet |            39.2 |
# |          MaxEpRet |             148 |
# |          MinEpRet |            62.3 |
# |             EpLen |             932 |
# |      AverageVVals |            7.85 |
# |          StdVVals |            7.78 |
# |          MaxVVals |            44.3 |
# |          MinVVals |           -7.12 |
# | TotalEnvInteracts |         2.5e+05 |
# |            LossPi |        2.93e-09 |
# |             LossV |             131 |
# |       DeltaLossPi |         -0.0063 |
# |        DeltaLossV |           -23.1 |
# |           Entropy |            0.89 |
# |                KL |          0.0105 |
# |          ClipFrac |          0.0732 |
# |          StopIter |              79 |
# |              Time |             251 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 784 steps.
# ---------------------------------------
# |             Epoch |              50 |
# |      AverageEpRet |            73.2 |
# |          StdEpRet |            84.7 |
# |          MaxEpRet |             173 |
# |          MinEpRet |           -79.1 |
# |             EpLen |             843 |
# |      AverageVVals |            10.1 |
# |          StdVVals |            10.9 |
# |          MaxVVals |             103 |
# |          MinVVals |             -11 |
# | TotalEnvInteracts |        2.55e+05 |
# |            LossPi |       -1.55e-10 |
# |             LossV |             516 |
# |       DeltaLossPi |         -0.0116 |
# |        DeltaLossV |            -274 |
# |           Entropy |           0.877 |
# |                KL |          0.0109 |
# |          ClipFrac |           0.117 |
# |          StopIter |              79 |
# |              Time |             256 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 504 steps.
# ---------------------------------------
# |             Epoch |              51 |
# |      AverageEpRet |            56.3 |
# |          StdEpRet |            73.7 |
# |          MaxEpRet |             135 |
# |          MinEpRet |           -43.4 |
# |             EpLen |             749 |
# |      AverageVVals |            4.33 |
# |          StdVVals |            10.3 |
# |          MaxVVals |            65.6 |
# |          MinVVals |           -14.6 |
# | TotalEnvInteracts |         2.6e+05 |
# |            LossPi |        7.91e-10 |
# |             LossV |             285 |
# |       DeltaLossPi |        -0.00718 |
# |        DeltaLossV |             -54 |
# |           Entropy |            0.85 |
# |                KL |         0.00832 |
# |          ClipFrac |          0.0732 |
# |          StopIter |              79 |
# |              Time |             260 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 383 steps.
# Early stopping at step 6 due to reaching max kl.
# ---------------------------------------
# |             Epoch |              52 |
# |      AverageEpRet |            74.9 |
# |          StdEpRet |            93.7 |
# |          MaxEpRet |             180 |
# |          MinEpRet |           -64.1 |
# |             EpLen |             770 |
# |      AverageVVals |            4.59 |
# |          StdVVals |            11.8 |
# |          MaxVVals |            88.2 |
# |          MinVVals |           -35.9 |
# | TotalEnvInteracts |        2.65e+05 |
# |            LossPi |        -1.2e-09 |
# |             LossV |             574 |
# |       DeltaLossPi |        -0.00307 |
# |        DeltaLossV |            -162 |
# |           Entropy |           0.872 |
# |                KL |          0.0193 |
# |          ClipFrac |           0.264 |
# |          StopIter |               6 |
# |              Time |             265 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              53 |
# |      AverageEpRet |            65.4 |
# |          StdEpRet |            18.9 |
# |          MaxEpRet |            89.2 |
# |          MinEpRet |            41.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            7.09 |
# |          StdVVals |             8.8 |
# |          MaxVVals |            52.7 |
# |          MinVVals |           -23.9 |
# | TotalEnvInteracts |         2.7e+05 |
# |            LossPi |       -1.19e-09 |
# |             LossV |            79.7 |
# |       DeltaLossPi |         -0.0123 |
# |        DeltaLossV |           -58.7 |
# |           Entropy |           0.844 |
# |                KL |          0.0145 |
# |          ClipFrac |           0.181 |
# |          StopIter |              79 |
# |              Time |             271 |
# ---------------------------------------
# ---------------------------------------
# |             Epoch |              54 |
# |      AverageEpRet |            75.6 |
# |          StdEpRet |            16.5 |
# |          MaxEpRet |             101 |
# |          MinEpRet |            53.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            2.37 |
# |          StdVVals |            8.35 |
# |          MaxVVals |            49.1 |
# |          MinVVals |           -11.1 |
# | TotalEnvInteracts |        2.75e+05 |
# |            LossPi |       -2.48e-08 |
# |             LossV |            26.3 |
# |       DeltaLossPi |        -0.00833 |
# |        DeltaLossV |           -15.6 |
# |           Entropy |           0.937 |
# |                KL |         0.00202 |
# |          ClipFrac |          0.0462 |
# |          StopIter |              79 |
# |              Time |             277 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 275 steps.
# ---------------------------------------
# |             Epoch |              55 |
# |      AverageEpRet |            82.7 |
# |          StdEpRet |            34.6 |
# |          MaxEpRet |             147 |
# |          MinEpRet |            44.5 |
# |             EpLen |             945 |
# |      AverageVVals |            7.25 |
# |          StdVVals |            10.3 |
# |          MaxVVals |            60.8 |
# |          MinVVals |           -11.6 |
# | TotalEnvInteracts |         2.8e+05 |
# |            LossPi |        1.35e-08 |
# |             LossV |             109 |
# |       DeltaLossPi |        -0.00787 |
# |        DeltaLossV |           -42.1 |
# |           Entropy |             0.9 |
# |                KL |          0.0104 |
# |          ClipFrac |            0.11 |
# |          StopIter |              79 |
# |              Time |             282 |
# ---------------------------------------
# Warning: trajectory cut off by epoch at 377 steps.
# ---------------------------------------
# |             Epoch |              56 |
# |      AverageEpRet |            82.7 |
# |          StdEpRet |              39 |
# |          MaxEpRet |             159 |
# |          MinEpRet |            55.2 |
# |             EpLen |             925 |
# |      AverageVVals |            6.92 |
# |          StdVVals |            10.9 |
# |          MaxVVals |            76.9 |
# |          MinVVals |           -11.2 |
# | TotalEnvInteracts |        2.85e+05 |
# |            LossPi |        4.91e-09 |
# |             LossV |              86 |
# |       DeltaLossPi |        -0.00659 |
# |        DeltaLossV |             -18 |
# |           Entropy |           0.894 |
# |                KL |         0.00854 |
# |          ClipFrac |            0.11 |
# |          StopIter |              79 |
# |              Time |             288 |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-872b672f78a9> in <module>
#       2
#       3 ppo(env_fn=env_fn, ac_kwargs=ac_kwargs, steps_per_epoch=5000,
# ----> 4     epochs=250, logger_kwargs=logger_kwargs)
#
# ~/user/spinningup/spinup/algos/pytorch/ppo/ppo.py in ppo(env_fn, actor_critic, ac_kwargs, seed, steps_per_epoch, epochs, gamma, clip_ratio, pi_lr, vf_lr, train_pi_iters, train_v_iters, lam, max_ep_len, target_kl, logger_kwargs, save_freq)
#     298     for epoch in range(epochs):
#     299         for t in range(local_steps_per_epoch):
# --> 300             a, v, logp = ac.step(torch.as_tensor(o, dtype=torch.float32))
#     301
#     302             next_o, r, d, _ = env.step(a)
#
# ~/user/spinningup/spinup/algos/pytorch/ppo/core.py in step(self, obs)
#     126     def step(self, obs):
#     127         with torch.no_grad():
# --> 128             pi = self.pi._distribution(obs)
#     129             a = pi.sample()
#     130             logp_a = self.pi._log_prob_from_distribution(pi, a)
#
# ~/user/spinningup/spinup/algos/pytorch/ppo/core.py in _distribution(self, obs)
#      71
#      72     def _distribution(self, obs):
# ---> 73         logits = self.logits_net(obs)
#      74         return Categorical(logits=logits)
#      75
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/miniconda3/envs/spinningup/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
# -> 1372         output = input.matmul(weight.t())
#    1373         if bias is not None:
#    1374             output += bias
#
# KeyboardInterrupt:

# %%
### Using ExperimentalGrid to train multiple configurations (for hyperparameters) of the same algorithm sequentially

from spinup.utils.run_utils import ExperimentGrid
import argparse
import sys

sys.argv = ['01_experiments', '--cpu', '4', '--num_runs', '3']

parser = argparse.ArgumentParser()
parser.add_argument('--cpu', type=int, default=4)
parser.add_argument('--num_runs', type=int, default=3)
args = parser.parse_args()

eg = ExperimentGrid(name='ppo-pyt-bench')
eg.add('env_name', 'CartPole-v0', '', True)
eg.add('seed', [10*i for i in range(args.num_runs)])
eg.add('epochs', 10)
eg.add('steps_per_epoch', 4000)
eg.add('ac_kwargs:hidden_sizes', [(32, ), (64, 64)], 'hid')
eg.add('ac_kwargs:activation', [torch.nn.Tanh, torch.nn.ReLU], '')
eg.run(ppo, num_cpu=args.cpu)
# Out:
# ================================================================================
# ExperimentGrid [ppo-pyt-bench] runs over parameters:
#
#  env_name                                 []
#
# 	CartPole-v0
#
#  seed                                     [see]
#
# 	0
# 	10
# 	20
#
#  epochs                                   [epo]
#
# 	10
#
#  steps_per_epoch                          [ste]
#
# 	4000
#
#  ac_kwargs:hidden_sizes                   [hid]
#
# 	(32,)
# 	(64, 64)
#
#  ac_kwargs:activation                     []
#
# 	Tanh
# 	ReLU
#
#  Variants, counting seeds:               12
#  Variants, not counting seeds:           4
#
# ================================================================================
#
# Preparing to run the following experiments...
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
# ppo-pyt-bench_cartpole-v0_hid32_tanh
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# ================================================================================
#
# Launch delayed to give you a few seconds to review your experiments.
#
# To customize or disable this behavior, change WAIT_BEFORE_LAUNCH in
# spinup/user_config.py.
#
# ================================================================================
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	0,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s0
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s0
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	10,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s10
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s10
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_tanh/ppo-pyt-bench_cartpole-v0_hid32_tanh_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid32_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             32
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid32_relu/ppo-pyt-bench_cartpole-v0_hid32_relu_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_tanh
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"Tanh",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_tanh/ppo-pyt-bench_cartpole-v0_hid64-64_tanh_s20
#
#
# ================================================================================
#
#
#
#
#
# Running experiment:
#
# ppo-pyt-bench_cartpole-v0_hid64-64_relu
#
# with kwargs:
#
# {
#     "ac_kwargs":	{
#         "activation":	"ReLU",
#         "hidden_sizes":	[
#             64,
#             64
#         ]
#     },
#     "env_name":	"CartPole-v0",
#     "epochs":	10,
#     "seed":	20,
#     "steps_per_epoch":	4000
# }
#
#
#
#
#
#
#
# ================================================================================
# End of experiment.
#
#
# Plot results from this run with:
#
# python -m spinup.run plot /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s20
#
#
# Watch the trained agent with:
#
# python -m spinup.run test_policy /home/sherif/user/spinningup/data/ppo-pyt-bench_cartpole-v0_hid64-64_relu/ppo-pyt-bench_cartpole-v0_hid64-64_relu_s20
#
#
# ================================================================================

# %%
### Simulating trained policies (Doesn't work inside Jupyter Notebooks)

from spinup.utils.test_policy import load_policy_and_env, run_policy
_, get_action = load_policy_and_env('/home/sherif/user/python/spinningup/data')
env = gym.make('LunarLander-v2')
run_policy(env, get_action)
